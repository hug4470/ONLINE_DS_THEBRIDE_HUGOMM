# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0,5,10)
x
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
plt.figure()

plt.subplot(1,2,1)
plt.plot(x,3*x, "-");

plt.subplot(1,2,2)
plt.plot(x,-3*x-5, "-");

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
plt.figure()

plt.subplot(1,2,1)
plt.plot(x,3*x, "-");
plt.xlim(0,5)
plt.ylim(-15,15)

plt.subplot(1,2,2)
plt.plot(x,-3*x-5, "-");
plt.xlim(0,5)
plt.ylim(-15,15);

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
plt.figure()

plt.subplot(1,2,1)
plt.plot(x,3*x, "-");
plt.xlim(0,5)
plt.ylim(-15,15)
plt.title("recta sube")
plt.xlabel("eje X")
plt.ylabel("eje Y")

plt.subplot(1,2,2)
plt.plot(x,-3*x-5, "-");
plt.xlim(0,5)
plt.ylim(-15,15);
plt.title("recta baja")
plt.xlabel("eje X")
# plt.ylabel("eje Y");
# Out:
# Text(0.5, 0, 'eje X')

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0,5,10)
plt.plot(x,3*x, "-")
plt.xlim(np.linspace(0,5,2))
plt.ylim(-15,15)
plt.title("recta sube")
plt.xlabel("eje X")
plt.ylabel("eje Y");

# %%
plt.plot(x,-3*x-5, "-");
plt.xlim(np.linspace(0,5,2))
plt.ylim(-15,15);
plt.title("recta baja")
plt.xlabel("eje X")
plt.ylabel("eje Y");

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
coorX = [20,22,24,26,28]
coorY = [5,15,-5,20,5]
plt.bar(coorX, coorY, width = 1.5);

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
ejex = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
ejey = [160, 180, 175, 190, 170]
plt.bar(ejex, ejey, width = 0.8, color = "g")
plt.title("Alturas")
plt.xlabel("Nombres")
plt.ylabel("cm");

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
ejex = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
ejey = [160, 180, 175, 190, 170]
plt.bar(ejex, ejey, width = 0.8, color = "g")
plt.title("Alturas")
plt.xlabel("Nombres")
plt.ylabel("cm")
plt.figure(figsize=(3,5));

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
ejex = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
ejey = [160, 180, 175, 190, 170]
plt.bar(ejex, ejey, width = 0.8, color = "g")
plt.yticks([])
plt.title("Alturas")
plt.xlabel("Nombres")
plt.ylabel("cm")
plt.figure(figsize=(3,5));

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
ejex = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
ejey = [160, 180, 175, 190, 170]
plt.barh(ejex, ejey, height = 0.8, color = "g")
# plt.yticks([])
plt.title("Alturas")
plt.xlabel("cm")
plt.ylabel("Nombres")
plt.figure(figsize=(3,5));

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
ejex = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
ejey = [160, 180, 175, 190, 170]

fig, ax = plt.subplots()
ax.bar(ejex, ejey, width=  0.8, color = "g")
ax.set_title("Alturas")
ax.set_xlabel("cm")
ax.set_ylabel("Nombres")
ax.invert_yaxis()
ax.invert_xaxis()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
ejex = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
ejey = [160, 180, 175, 190, 170]

fig, ax = plt.subplots()
ax.bar(ejex, ejey, width=  0.8, color = "g")
ax.set_title("Alturas")
ax.set_xlabel("cm")
ax.set_ylabel("Nombres")
ax.invert_yaxis()
ax.invert_xaxis()
plt.style.use("dark_background")

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
import pandas as pd
ventas = pd.DataFrame({ "Year" : [2015,2016,2017,2018,2019], 
                   "Sold_items_A" : [1000,3500,4000,5500,7000]})
ventas.set_index("Year", inplace=True)
ventas
# Out:
#       Sold_items_A
# Year
# 2015          1000
# 2016          3500
# 2017          4000
# 2018          5500
# 2019          7000

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.use('seaborn-v0_8-white')
plt.plot(ventas.index,ventas['Sold_items_A'],'--g')
plt.title("Volumen ventas entre 2015-2019")
plt.xlabel("Años");

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
ventas["Sold_items_B"] = [2000, 3100, 5000, 4000, 6000]
ventas
# Out:
#       Sold_items_A  Sold_items_B
# Year
# 2015          1000          2000
# 2016          3500          3100
# 2017          4000          5000
# 2018          5500          4000
# 2019          7000          6000

# %%
plt.style.use('seaborn-v0_8-white')
plt.plot(ventas.index,ventas['Sold_items_A'],'--g', ventas['Sold_items_B'], ':r')
plt.title("Volumen ventas entre 2015-2019");

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
# ventas.plot(x = "Sold_items_A", y = ventas.index, kind = "scatter")

plt.scatter(ventas.index, ventas['Sold_items_A'])

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
plt.pie(ventas.index, ventas['Sold_items_A'])

# ventas.plot(x = "Sold_items_A", y = ventas.index, kind = "pie")
# Out:
# ([<matplotlib.patches.Wedge at 0x27e426457f0>,
#   <matplotlib.patches.Wedge at 0x27e449c3750>,
#   <matplotlib.patches.Wedge at 0x27e449c3110>,
#   <matplotlib.patches.Wedge at 0x27e449c2e90>,
#   <matplotlib.patches.Wedge at 0x27e449c2c10>],
#  [Text(810.2733664520667, 587.9271057014081, ''),
#   Text(-1076.7122894256672, 3331.424898718225, ''),
#   Text(-4001.0930109044966, 7.4785086206929545, ''),
#   Text(-1708.0797630641962, -5229.203068633934, ''),
#   Text(5661.444744590232, -4118.670248266015, '')])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 1428531x1265609 pixels is too large. It must be less than 2^16 in each direction.

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
alturas = np.random.randint(150, 191, size=300)
df_alturas = pd.DataFrame({'Altura': alturas})

df_alturas.plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>
