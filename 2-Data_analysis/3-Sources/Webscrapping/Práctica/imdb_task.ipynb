# %% [markdown]
# ## Web scrapping de IMDB

# %% [markdown]
# Descarga la información correspondiente y guarda en un csv el top de las 250 películas mediante webscrapping. Encapsúlalo en un script.
#
# Obtén:
# * Título
# * Año
# * Duración
# * Posición
# * Rating

# %%
url = "https://www.imdb.com/chart/top/?ref_=nv_mv_250"

# %%
# Si la petición te devuelve un 403, puedes probar con:
# !pip install fake-useragent
from fake_useragent import UserAgent
import requests
ua = UserAgent()
headers = {'User-Agent': ua.random}
response = requests.get(url, headers=headers)
print(response)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
# from splinter import Browser
import numpy as np

pd.set_option('max_colwidth', 800)

# %%
html = response.content

# %%
soup = bs(html, 'html.parser')

# %%
dict_peliculas = {"Titulos"  : [],
                "Rating" : [],
                "Año" : [],
                "Duración" : []}

for enlace in soup.find_all("h3", class_ = "ipc-title__text")[1:26]:
    dict_peliculas["Titulos"].append(enlace.get_text())
    # print(enlace.get_text())

for enlace in soup.find_all("span", class_ = "ipc-rating-star--rating")[:25]:
    dict_peliculas["Rating"].append(enlace.get_text())
    # print(enlace.get_text())

for enlace in soup.find_all("span", class_ ="sc-ab348ad5-8 cSWcJI cli-title-metadata-item")[:75:3]:
    dict_peliculas["Año"].append(enlace.get_text())
    # print(enlace.get_text())

for enlace in soup.find_all("span", class_ ="sc-ab348ad5-8 cSWcJI cli-title-metadata-item")[1:75:3]:
    dict_peliculas["Duración"].append(enlace.get_text())

df = pd.DataFrame(dict_peliculas)
df.index = range(1, len(df) +1)

df = df.rename_axis('Posición', axis='index')

df
# Out:
#                                                       Titulos Rating   Año  \
# Posición
# 1                                          1. Cadena perpetua    9.3  1994
# 2                                               2. El padrino    9.2  1972
# 3                                      3. El caballero oscuro    9.0  2008
# 4                                      4. El padrino parte II    9.0  1974
# 5                                    5. 12 hombres sin piedad    9.0  1957
# 6              6. El señor de los anillos: El retorno del rey    9.0  2003
# 7                                    7. La lista de Schindler    9.0  1993
# 8                                             8. Pulp Fiction    8.9  1994
# 9         9. El señor de los anillos: La comunidad del anillo    8.9  2001
# 10                             10. El bueno, el feo y el malo    8.8  1966
# 11                                           11. Forrest Gump    8.8  1994
# 12                12. El señor de los anillos: Las dos torres    8.8  2002
# 13                                    13. El club de la lucha    8.8  1999
# 14                                                 14. Origen    8.8  2010
# 15                                 15. El imperio contraataca    8.7  1980
# 16                                                 16. Matrix    8.7  1999
# 17                                    17. Uno de los nuestros    8.7  1990
# 18                    18. Alguien voló sobre el nido del cuco    8.7  1975
# 19                                           19. Interstellar    8.7  2014
# 20                                                  20. Seven    8.6  1995
# 21                                   21. ¡Qué bello es vivir!    8.6  1946
# 22                                     22. Los siete samuráis    8.6  1954
# 23                            23. El silencio de los corderos    8.6  1991
# 24                                 24. Salvar al soldado Ryan    8.6  1998
# 25                                         25. Ciudad de Dios    8.6  2002
#
#          Duración
# Posición
# 1          2h 22m
# 2          2h 55m
# 3          2h 32m
# 4          3h 22m
# 5          1h 36m
# 6          3h 21m
# 7          3h 15m
# 8          2h 34m
# 9          2h 58m
# 10          3h 2m
# 11         2h 22m
# 12         2h 59m
# 13         2h 19m
# 14         2h 28m
# 15          2h 4m
# 16         2h 16m
# 17         2h 25m
# 18         2h 13m
# 19         2h 49m
# 20          2h 7m
# 21         2h 10m
# 22         3h 27m
# 23         1h 58m
# 24         2h 49m
# 25         2h 10m

# %%
df.to_csv("imdb_scrap.csv")

# %%
print(soup.find_all("h3", class_ = "ipc-title__text")[24:28])
# Out:
# [<h3 class="ipc-title__text">24. Salvar al soldado Ryan</h3>, <h3 class="ipc-title__text">25. Ciudad de Dios</h3>, <h3 class="ipc-title__text">Recently viewed</h3>]

# %%
# dict_peliculas2 = {"Titulos"  : [],
#                 "Rating" : [],
#                   "Año" : [],
#                   "Duración" : []}

# for enlace in soup.find_all("h3", class_ = "ipc-title__text")[26:51]:
#     dict_peliculas["Titulos"].append(enlace.get_text())
#     # print(enlace.get_text())

# for enlace in soup.find_all("span", class_ = "ipc-rating-star--rating")[25:50]:
#     dict_peliculas["Rating"].append(enlace.get_text())
#     # print(enlace.get_text())

# for enlace in soup.find_all("span", class_ ="sc-ab348ad5-8 cSWcJI cli-title-metadata-item")[75:225:3]:
#     dict_peliculas["Año"].append(enlace.get_text())
#     # print(enlace.get_text())

# for enlace in soup.find_all("span", class_ ="sc-ab348ad5-8 cSWcJI cli-title-metadata-item")[76:225:3]:
#     dict_peliculas["Duración"].append(enlace.get_text())

# df2 = pd.DataFrame(dict_peliculas)
# df2.index = range(1, len(df) +1)

# df2 = df.rename_axis('Posición', axis='index')

# df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 21
#      18 for enlace in soup.find_all("span", class_ ="sc-ab348ad5-8 cSWcJI cli-title-metadata-item")[76:225:3]:
#      19     dict_peliculas["Duración"].append(enlace.get_text())
# ---> 21 df2 = pd.DataFrame(dict_peliculas)
#      22 df2.index = range(1, len(df) +1)
#      24 df2 = df.rename_axis('Posición', axis='index')
#
# File c:\Users\Hugo Trabajo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\Hugo Trabajo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\Hugo Trabajo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\Hugo Trabajo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
print(soup.find_all("ul"))
# Out:
# <ul aria-orientation="vertical" class="ipc-list navlinkcat__list ipc-list--baseAlt" role="menu"><a aria-disabled="false" class="ipc-list__item nav-link sc-khIhrF lmsYoz ipc-list__item--indent-one" href="https://help.imdb.com/imdb?ref_=cons_nb_hlp" role="menuitem" tabindex="-1"><span class="ipc-list-item__text" role="presentation">Help Center</span></a><a aria-disabled="false" class="ipc-list__item nav-link sc-khIhrF lmsYoz ipc-list__item--indent-one" href="https://contribute.imdb.com/czone?ref_=nv_cm_cz" role="menuitem" tabindex="-1"><span class="ipc-list-item__text" role="presentation">Contributor Zone</span></a><a aria-disabled="false" class="ipc-list__item nav-link sc-khIhrF lmsYoz ipc-list__item--indent-one" href="/poll/?ref_=nv_cm_pl" role="menuitem" tabindex="-1"><span class="ipc-list-item__text" role="presentation">Polls</span></a></ul>
