# %% [markdown]
# # Obtén datos de la API de Marvel
#
# ![imagen](https://cdn.hobbyconsolas.com/sites/navi.axelspringer.es/public/styles/hc_1440x810/public/media/image/2021/09/marvel-2460339.jpg?itok=cBnC1CBi)

# %% [markdown]
# Te tendrás que [registrar](https://developer.marvel.com/) y consultar la [documentación](https://developer.marvel.com/docs)

# %% [markdown]
# Queremos que consultes a la api para que te devuelva la info de los personajes de marvel que empiecen por la inicial de tu nombre. Deberemos guardarlos en un csv la información con la siguiente estructura
#
# ![imagen](./img/Captura_marvel.PNG)

# %% [markdown]
# Aquí te dejamos el código en python para poder empezar a hacer las llamadas, rellenando algunas variables como tus keys, parámetros de la llamada y la url (endpoint) a la que quieres acceder

# %%
import hashlib
import requests
import datetime
import pandas as pd

# pd.set_option('display.max_columns', 200)<<
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_colwidth', 100)

# %%
def hash_params(timestamp,priv_key,pub_key):
    """ Marvel API requires server side API calls to include
    md5 hash of timestamp + public key + private key """

    hash_md5 = hashlib.md5()
    hash_md5.update(f'{timestamp}{priv_key}{pub_key}'.encode('utf-8'))
    hashed_params = hash_md5.hexdigest()

    return hashed_params

# %%
timestamp = datetime.datetime.now().strftime('%Y-%m-%d%H:%M:%S')



pub_key = 'b1795d6b236cf7e0fbeb1692f4fddeab'
priv_key = 'cf87821145e08ab1a18dc1ff14cd25e10ed4af1b'

params = {'ts': timestamp, 
    'apikey': pub_key, 
    'hash': hash_params(timestamp, priv_key, pub_key),
    'nameStartsWith': 'H',
    'offset': 0,
    'limit': 100}

url = 'http://gateway.marvel.com/v1/public/characters'

res = requests.get(url,params=params)

# %%
data = res.json()
characters = data['data']['results']

for character in characters:
    thumbnail = character['thumbnail']
    character['picture_url'] = thumbnail['path'] + '.' + thumbnail['extension']
        
df_characters = pd.DataFrame(characters)
df_characters = df_characters[['id', 'name', 'picture_url']]

data
# Out:
# {'code': 200,
#  'status': 'Ok',
#  'copyright': '© 2024 MARVEL',
#  'attributionText': 'Data provided by Marvel. © 2024 MARVEL',
#  'attributionHTML': '<a href="http://marvel.com">Data provided by Marvel. © 2024 MARVEL</a>',
#  'etag': 'b7a450dc82c217834025671b5878a516c33d268a',
#  'data': {'offset': 0,
#   'limit': 100,
#   'total': 74,
#   'count': 74,
#   'results': [{'id': 1011400,
#     'name': 'H.A.M.M.E.R.',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/6/c0/4ce5a7675d903',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011400',
#     'comics': {'available': 8,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011400/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/27543',
#        'name': 'Avengers: The Initiative (2007) #26'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/27544',
#        'name': 'Avengers: The Initiative (2007) #27'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/26195',
#        'name': 'Captain America: Reborn (2009) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/26196',
#        'name': 'Captain America: Reborn (2009) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/26198',
#        'name': 'Captain America: Reborn (2009) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/39788',
#        'name': 'CAPTAIN AMERICA: REBORN MGC 1 (2011) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/23948',
#        'name': 'Ms. Marvel (2006) #38'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/26966',
#        'name': 'Uncanny X-Men (1981) #513'}],
#      'returned': 8},
#     'series': {'available': 5,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011400/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/1945',
#        'name': 'Avengers: The Initiative (2007 - 2010)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/8213',
#        'name': 'Captain America: Reborn (2009 - 2010)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/14718',
#        'name': 'CAPTAIN AMERICA: REBORN MGC 1 (2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/987',
#        'name': 'Ms. Marvel (2006 - 2010)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2258',
#        'name': 'Uncanny X-Men (1981 - 2011)'}],
#      'returned': 5},
#     'stories': {'available': 11,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011400/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53113',
#        'name': 'Ms. Marvel (2006) #38',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53114',
#        'name': '1 of 3 New Ms. Marvel',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/57687',
#        'name': 'Captain America: Reborn (2009) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/57688',
#        'name': 'Interior #57688',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/57689',
#        'name': 'Captain America: Reborn (2009) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/57690',
#        'name': 'Interior #57690',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/57693',
#        'name': 'Captain America: Reborn (2009) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/57694',
#        'name': 'Interior #57694',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/59245',
#        'name': 'Interior #59245',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/60364',
#        'name': 'Avengers: The Initiative (2007) #26 - Int',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/60366',
#        'name': 'Avengers: The Initiative (2007) #27 - Int',
#        'type': 'interiorStory'}],
#      'returned': 11},
#     'events': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011400/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/318',
#        'name': 'Dark Reign'}],
#      'returned': 1},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/879/hammer.?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011400/hammer.?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/6/c0/4ce5a7675d903.jpg'},
#    {'id': 1009332,
#     'name': 'H.E.R.B.I.E.',
#     'description': '',
#     'modified': '2012-03-20T12:48:36-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/c/e0/4ce59fe9811cb',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009332',
#     'comics': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009332/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/70943',
#        'name': 'True Believers: Fantastic Four - The Coming of H.E.R.B.I.E. (2018) #1'}],
#      'returned': 1},
#     'series': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009332/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/25881',
#        'name': 'True Believers: Fantastic Four - The Coming of H.E.R.B.I.E. (2018)'}],
#      'returned': 1},
#     'stories': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009332/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/157861',
#        'name': 'cover from True Believers: Fantastic Four (2018) #1',
#        'type': 'cover'}],
#      'returned': 1},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009332/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/880/herbie.?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/H.E.R.B.I.E.?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009332/herbie.?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/c/e0/4ce59fe9811cb.jpg'},
#    {'id': 1011391,
#     'name': 'Hairball',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011391',
#     'comics': {'available': 8,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011391/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/36651',
#        'name': 'Avengers Vs. Pet Avengers (2010) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/36654',
#        'name': 'Avengers Vs. Pet Avengers (2010) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/36652',
#        'name': 'Avengers Vs. Pet Avengers (2010) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/36653',
#        'name': 'Avengers Vs. Pet Avengers (2010) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/24258',
#        'name': 'Lockjaw and the Pet Avengers (2009) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/25617',
#        'name': 'Lockjaw and the Pet Avengers (2009) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/25619',
#        'name': 'Lockjaw and the Pet Avengers (2009) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/25621',
#        'name': 'Lockjaw and the Pet Avengers (2009) #4'}],
#      'returned': 8},
#     'series': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011391/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/13032',
#        'name': 'Avengers Vs. Pet Avengers (2010 - 2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/7451',
#        'name': 'Lockjaw and the Pet Avengers (2009)'}],
#      'returned': 2},
#     'stories': {'available': 12,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011391/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53744',
#        'name': '4XLS 1 of 4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/56481',
#        'name': 'Cover #56481',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/56485',
#        'name': 'Cover #56485',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/56490',
#        'name': 'Interior #56490',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81326',
#        'name': 'Avengers Vs. Pet Avengers (2010) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81327',
#        'name': 'Interior #81327',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81328',
#        'name': 'Avengers Vs. Pet Avengers (2010) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81329',
#        'name': 'Interior #81329',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81330',
#        'name': 'Avengers Vs. Pet Avengers (2010) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81331',
#        'name': 'Interior #81331 ',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81332',
#        'name': 'Avengers Vs. Pet Avengers (2010) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/81333',
#        'name': 'Interior #81333',
#        'type': 'interiorStory'}],
#      'returned': 12},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011391/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/889/hairball?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011391/hairball?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg'},
#    {'id': 1009333,
#     'name': 'Half-Life (Tony Masterson)',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/a/20/4ce59ff485b35',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009333',
#     'comics': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009333/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9153',
#        'name': 'Incredible Hulk (1962) #342'}],
#      'returned': 1},
#     'series': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009333/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/2021',
#        'name': 'Incredible Hulk (1962 - 1999)'}],
#      'returned': 1},
#     'stories': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009333/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/18833',
#        'name': 'Incredible Hulk (1962) #342',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/18834',
#        'name': 'No Human Fears',
#        'type': 'interiorStory'}],
#      'returned': 2},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009333/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/891/half-life?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Half-Life%20(Tony%20Masterson)?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009333/half-life_tony_masterson?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/a/20/4ce59ff485b35.jpg'},
#    {'id': 1009334,
#     'name': 'Hammerhead',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/5/c0/4c003ee47c207',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009334',
#     'comics': {'available': 34,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009334/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/76864',
#        'name': 'Adventures of Spider-Man (1996) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30317',
#        'name': 'Amazing Spider-Man (1999) #642'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22372',
#        'name': 'Amazing Spider-Man Family (2008) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/23069',
#        'name': 'Amazing Spider-Man: Extra! (2008) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/112117',
#        'name': 'Amazing Spider-Man: Gang War First Strike (2023) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22455',
#        'name': 'Daredevil Saga (2008) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/62414',
#        'name': 'Power Man and Iron Fist (1978) #92'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22203',
#        'name': 'Punisher War Journal (1988) #47'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/14611',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976) #161'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/14613',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976) #163'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/14615',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976) #165'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/14616',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976) #166'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/14659',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976) #204'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/55698',
#        'name': 'Spider-Man (2016) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/61074',
#        'name': 'Spider-Man (2016) #17'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10915',
#        'name': "Spider-Man's Tangled Web (2001) #14"},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/62222',
#        'name': 'SPIDER-MAN: MILES MORALES VOL. 3 (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38126',
#        'name': 'Spider-Man: New York Stories (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/1007',
#        'name': "SPIDER-MAN: SPIDER-MAN'S TANGLED WEB (Trade Paperback)"},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/62858',
#        'name': 'SPIDER-MAN: THE LIFELINE TABLET SAGA (Trade Paperback)'}],
#      'returned': 20},
#     'series': {'available': 19,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009334/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/27587',
#        'name': 'Adventures of Spider-Man (1996 - 1997)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/454',
#        'name': 'Amazing Spider-Man (1999 - 2013)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/5376',
#        'name': 'Amazing Spider-Man Family (2008 - 2009)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/6604',
#        'name': 'Amazing Spider-Man: Extra! (2008 - 2009)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/38646',
#        'name': 'Amazing Spider-Man: Gang War First Strike (2023)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/6073',
#        'name': 'Daredevil Saga (2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2271',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976 - 1998)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/20674',
#        'name': 'Power Man and Iron Fist (1978 - 1986)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/5860',
#        'name': 'Punisher War Journal (1988 - 1995)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/20508',
#        'name': 'Spider-Man (2016 - 2018)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2071',
#        'name': "Spider-Man's Tangled Web (2001 - 2003)"},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/22845',
#        'name': 'SPIDER-MAN: MILES MORALES VOL. 3 (2017)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/13721',
#        'name': 'Spider-Man: New York Stories (2011 - Present)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/69',
#        'name': "SPIDER-MAN: SPIDER-MAN'S TANGLED WEB (2002)"},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/23056',
#        'name': 'SPIDER-MAN: THE LIFELINE TABLET SAGA (2017)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1987',
#        'name': 'The Amazing Spider-Man (1963 - 1998)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/32866',
#        'name': 'The Amazing Spider-Man (2022 - Present)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2262',
#        'name': 'Wolverine (1988 - 2003)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/84',
#        'name': 'WOLVERINE/DEADPOOL: WEAPON X (1999)'}],
#      'returned': 19},
#     'stories': {'available': 39,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009334/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13572',
#        'name': 'Cover #13572',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13608',
#        'name': 'Hammerhead Is Out!',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13670',
#        'name': 'Cover #13670',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13672',
#        'name': 'Cover #13672',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13959',
#        'name': 'Gang War Part 1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13960',
#        'name': 'And Who Shall Stand Against Them?',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13961',
#        'name': 'Gang War Part 2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13962',
#        'name': 'The Arranger Must Die!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/23726',
#        'name': 'Cover #23726',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/23727',
#        'name': 'Blood Simple',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/25418',
#        'name': 'The Last Shoot',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/28708',
#        'name': 'The Hunted Part 3',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/29668',
#        'name': 'Pardoned!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/29672',
#        'name': 'The Carrion Cure',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/29676',
#        'name': 'Knight and Fogg',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/29678',
#        'name': 'The Deadly Lads From Liverpool',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/29790',
#        'name': 'Death by Tombstone, Part 1: Takeover!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/49031',
#        'name': 'Interior #49031',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/49246',
#        'name': 'AMAZING SPIDER-MAN FAMILY (2008) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/49247',
#        'name': 'Venom: Lethal Protector 5, Spider-Man: Mysterio Manifesto 2',
#        'type': 'interiorStory'}],
#      'returned': 20},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009334/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/896/hammerhead?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Hammerhead?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009334/hammerhead?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/5/c0/4c003ee47c207.jpg'},
#    {'id': 1014995,
#     'name': 'Hammerhead (Ultimate)',
#     'description': '',
#     'modified': '2012-07-11T09:13:15-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1014995',
#     'comics': {'available': 5,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1014995/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/62246',
#        'name': 'Ultimate Spider-Man Ultimate Collection Book 7 (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15703',
#        'name': 'Ultimate X-Men (2001) #13'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15704',
#        'name': 'Ultimate X-Men (2001) #14'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/2982',
#        'name': 'ULTIMATE X-MEN VOL. 3: WORLD TOUR TPB (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/1020',
#        'name': 'Ultimate X-Men Vol. III: World Tour (Trade Paperback)'}],
#      'returned': 5},
#     'series': {'available': 4,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1014995/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/22869',
#        'name': 'Ultimate Spider-Man Ultimate Collection Book 7 (2017)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/474',
#        'name': 'Ultimate X-Men (2001 - 2009)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1168',
#        'name': 'ULTIMATE X-MEN VOL. 3: WORLD TOUR TPB (2005)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/82',
#        'name': 'Ultimate X-Men Vol. III: World Tour (2002)'}],
#      'returned': 4},
#     'stories': {'available': 5,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1014995/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/32124',
#        'name': 'Previously ...',
#        'type': 'recap'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/32125',
#        'name': '[untitled]',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/32136',
#        'name': 'Previously ...',
#        'type': 'recap'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/32137',
#        'name': 'You Always Remember Your First Love Part 1',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/134877',
#        'name': 'cover from Ultimate Spider-Man Ultimate Collection (2017)',
#        'type': 'cover'}],
#      'returned': 5},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1014995/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/896/hammerhead?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1014995/hammerhead_ultimate?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg'},
#    {'id': 1011490,
#     'name': 'Hank Pym',
#     'description': ' ',
#     'modified': '2015-06-01T16:59:16-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/2/b0/5205305343bfd',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011490',
#     'comics': {'available': 243,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011490/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22461',
#        'name': 'Adam: Legend of the Blue Marvel (2008) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/23281',
#        'name': 'Amazing Adventures (1970) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/35533',
#        'name': 'Amazing Spider-Man (1999) #661'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/39041',
#        'name': 'Amazing Spider-Man (1999) #661 (X-Men Art Variant)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/35534',
#        'name': 'Amazing Spider-Man (1999) #662'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/36763',
#        'name': 'Ant-Man & Wasp (2010) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/36764',
#        'name': 'Ant-Man & Wasp (2010) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/6951',
#        'name': 'Avengers (1963) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/7332',
#        'name': 'Avengers (1963) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/6953',
#        'name': 'Avengers (1963) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/6975',
#        'name': 'Avengers (1963) #12'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17509',
#        'name': 'Avengers (1998) #27'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17510',
#        'name': 'Avengers (1998) #28'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17511',
#        'name': 'Avengers (1998) #29'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17513',
#        'name': 'Avengers (1998) #30'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17514',
#        'name': 'Avengers (1998) #31'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17515',
#        'name': 'Avengers (1998) #32'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17516',
#        'name': 'Avengers (1998) #33'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17517',
#        'name': 'Avengers (1998) #34'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17518',
#        'name': 'Avengers (1998) #35'}],
#      'returned': 20},
#     'series': {'available': 92,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011490/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/6079',
#        'name': 'Adam: Legend of the Blue Marvel (2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/6666',
#        'name': 'Amazing Adventures (1970 - 1976)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/454',
#        'name': 'Amazing Spider-Man (1999 - 2013)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/13082',
#        'name': 'Ant-Man & Wasp (2010 - 2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1991',
#        'name': 'Avengers (1963 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/354',
#        'name': 'Avengers (1998 - 2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3621',
#        'name': 'Avengers (1996 - 1997)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/9086',
#        'name': 'Avengers Academy (2010 - 2012)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/10037',
#        'name': 'Avengers Academy Vol 1 : Permanent Record TPB (2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/26448',
#        'name': 'Avengers Annual (2001)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1737',
#        'name': 'AVENGERS ASSEMBLE (2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1816',
#        'name': 'Avengers Assemble Vol. 4 (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2929',
#        'name': 'AVENGERS ASSEMBLE VOL. 5 TPB (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2384',
#        'name': 'Avengers Classic (2007 - 2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3971',
#        'name': 'Avengers Fairy Tales (2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2111',
#        'name': 'Avengers Forever (1998 - 1999)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/37267',
#        'name': 'Avengers Inc. (2023 - Present)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/94',
#        'name': 'Avengers Legends Vol. II: George Perez Book I (1999)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/93',
#        'name': 'AVENGERS LEGENDS: AVENGERS FOREVER (2002)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/9860',
#        'name': 'Avengers Origins: Ant-Man & the Wasp (2011)'}],
#      'returned': 20},
#     'stories': {'available': 335,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011490/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/1500',
#        'name': 'Interior #1500',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3193',
#        'name': 'Interior #3193',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5496',
#        'name': 'Irredeemable Ant-Man (2006) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5500',
#        'name': 'Irredeemable Ant-Man (2006) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5621',
#        'name': 'BEYOND! (2006) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5872',
#        'name': '1 of 7 - 7XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5884',
#        'name': '4 of 7 - 7XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5886',
#        'name': 'Cover #5886',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5903',
#        'name': '7 of 7 - 7XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5905',
#        'name': 'Cover #5905',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5907',
#        'name': 'Cover #5907',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/6950',
#        'name': 'GS FF 4; GS Aven 1; GS Def 4; GS S-H 1, GS Inv 1; GS X-Men; GS Creatures 1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/7767',
#        'name': 'Irredeemable Ant-Man (2006) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/8381',
#        'name': 'Avengers: The Initiative (2007) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/8383',
#        'name': '1 of 6 - 6XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/8682',
#        'name': '3 of 6 - Ultron; THE INITIATIVE BANNER',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12140',
#        'name': '[untitled]',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12141',
#        'name': 'The Return of the Ant-Man',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12142',
#        'name': 'The Doorway to Nowhere',
#        'type': 'mystery story'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12143',
#        'name': 'The Thing From Outer Space',
#        'type': 'mystery story'}],
#      'returned': 20},
#     'events': {'available': 8,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011490/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/238',
#        'name': 'Civil War'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/318',
#        'name': 'Dark Reign'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/302',
#        'name': 'Fear Itself'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/317',
#        'name': 'Inhumanity'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/255',
#        'name': 'Initiative'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/154',
#        'name': 'Onslaught'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/269',
#        'name': 'Secret Invasion'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/273',
#        'name': 'Siege'}],
#      'returned': 8},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/21/hank_pym?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Wasp_(Henry_Pym)?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011490/hank_pym?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/2/b0/5205305343bfd.jpg'},
#    {'id': 1011091,
#     'name': 'Hannibal King',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011091',
#     'comics': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011091/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/48441',
#        'name': 'Journey Into Mystery (1996) #520'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/48442',
#        'name': 'Journey Into Mystery (1996) #521'}],
#      'returned': 2},
#     'series': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011091/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/13569',
#        'name': 'Journey Into Mystery (1996 - 1998)'}],
#      'returned': 1},
#     'stories': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011091/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/113152',
#        'name': 'Cover from Journey Into Mystery (1996) #521',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/113153',
#        'name': 'Cover from Journey Into Mystery (1996) #520',
#        'type': 'cover'}],
#      'returned': 2},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011091/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2871/hannibal_king?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Hannibal%20King?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011091/hannibal_king?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg'},
#    {'id': 1009348,
#     'name': 'Happy Hogan',
#     'description': '',
#     'modified': '2010-11-03T10:00:46-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/8/50/4ce5a00362b2c',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009348',
#     'comics': {'available': 18,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009348/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/67603',
#        'name': 'Age of Innocence: The Rebirth of Iron Man (1996) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9505',
#        'name': 'Iron Man (1968) #26'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9590',
#        'name': 'Iron Man (1968) #37'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9619',
#        'name': 'Iron Man (1968) #63'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9620',
#        'name': 'Iron Man (1968) #64'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/19941',
#        'name': 'Iron Man (1998) #65'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9621',
#        'name': 'Iron Man (1968) #65'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/19942',
#        'name': 'Iron Man (1998) #66'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9622',
#        'name': 'Iron Man (1968) #66'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/19943',
#        'name': 'Iron Man (1998) #67'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9623',
#        'name': 'Iron Man (1968) #67'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/19944',
#        'name': 'Iron Man (1998) #68'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/19945',
#        'name': 'Iron Man (1998) #69'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9627',
#        'name': 'Iron Man (1968) #70'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9541',
#        'name': 'Iron Man (1968) #292'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9546',
#        'name': 'Iron Man (1968) #297'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/9551',
#        'name': 'Iron Man (1968) #300'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/72687',
#        'name': 'Iron Man: The Iron Age (1998) #2'}],
#      'returned': 18},
#     'series': {'available': 4,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009348/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/24380',
#        'name': 'Age of Innocence: The Rebirth of Iron Man (1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2029',
#        'name': 'Iron Man (1968 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2572',
#        'name': 'Iron Man (1998 - 2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/26266',
#        'name': 'Iron Man: The Iron Age (1998)'}],
#      'returned': 4},
#     'stories': {'available': 32,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009348/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19491',
#        'name': 'Duel In a Dark Dimension',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19561',
#        'name': 'Iron Man (1968) #292',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19562',
#        'name': 'Mixed Reactions',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19578',
#        'name': 'Iron Man (1968) #300',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19659',
#        'name': 'In This Hour of Earthdoom',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19719',
#        'name': 'Enter:  Dr. Spectrum',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19721',
#        'name': 'Rokk Cometh!',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19723',
#        'name': 'The Cutting Edge of Death!',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19725',
#        'name': 'Battle Royal!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19727',
#        'name': 'Return of the Freak',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19735',
#        'name': 'Who Shall Stop...Ultimo?',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42755',
#        'name': 'Iron Man (1998) #65',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42756',
#        'name': 'Manhunt: Part One',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42757',
#        'name': 'Iron Man (1998) #66',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42758',
#        'name': 'Manhunt: Part Two',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42759',
#        'name': 'Iron Man (1998) #67',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42760',
#        'name': 'Manhunt: Part Three',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42761',
#        'name': 'Iron Man (1998) #68',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42762',
#        'name': 'Manhunt: Part Four',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42763',
#        'name': 'Iron Man (1998) #69',
#        'type': 'cover'}],
#      'returned': 20},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009348/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2715/happy_hogan?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Hogan,_Happy?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009348/happy_hogan?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/8/50/4ce5a00362b2c.jpg'},
#    {'id': 1010821,
#     'name': 'Hardball',
#     'description': '',
#     'modified': '2014-04-29T14:43:14-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/60/535ff2b245409',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1010821',
#     'comics': {'available': 17,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010821/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/13489',
#        'name': 'Avengers: The Initiative (2007) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15869',
#        'name': 'Avengers: The Initiative (2007) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15976',
#        'name': 'Avengers: The Initiative (2007) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/16162',
#        'name': 'Avengers: The Initiative (2007) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/16542',
#        'name': 'Avengers: The Initiative (2007) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20679',
#        'name': 'Avengers: The Initiative (2007) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20877',
#        'name': 'Avengers: The Initiative (2007) #11'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/21012',
#        'name': 'Avengers: The Initiative (2007) #12'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22299',
#        'name': 'Avengers: The Initiative (2007) #18'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22506',
#        'name': 'Avengers: The Initiative (2007) #19'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22912',
#        'name': 'Avengers: The Initiative (2007) #20'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17293',
#        'name': 'AVENGERS: THE INITIATIVE ANNUAL 1 (2007) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38447',
#        'name': 'Fear Itself: Youth in Revolt (2011) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38449',
#        'name': 'Fear Itself: Youth in Revolt (2011) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38448',
#        'name': 'Fear Itself: Youth in Revolt (2011) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38444',
#        'name': 'Fear Itself: Youth in Revolt (2011) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38446',
#        'name': 'Fear Itself: Youth in Revolt (2011) #6'}],
#      'returned': 17},
#     'series': {'available': 3,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010821/series',
# ...
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/22649',
#        'name': 'Occupy Avengers (2016 - 2017)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2271',
#        'name': 'Peter Parker, the Spectacular Spider-Man (1976 - 1998)'}],
#      'returned': 9},
#     'stories': {'available': 25,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009360/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/912',
#        'name': 'Fantastic Four (1998) #512',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/913',
#        'name': 'Interior #913',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/914',
#        'name': 'Fantastic Four (1998) #516',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/915',
#        'name': 'Interior #915',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/916',
#        'name': 'Fantastic Four (1998) #513',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/917',
#        'name': 'Interior #917',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/918',
#        'name': 'Fantastic Four (1998) #514',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/919',
#        'name': 'Interior #919',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12941',
#        'name': 'Fantastic Four (1961) #326',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12942',
#        'name': 'The Illusion',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12943',
#        'name': 'Fantastic Four (1961) #327',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12944',
#        'name': 'Why?!!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12945',
#        'name': 'Fantastic Four (1961) #328',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12946',
#        'name': 'Bad Dream!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12958',
#        'name': 'The Dream is Dead Part Two',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12964',
#        'name': 'Fantastic Four (1961) #336',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12965',
#        'name': 'Dark Congress!',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/29665',
#        'name': "The Fear and the Fury or: The Metal in Men's Souls",
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/31698',
#        'name': 'Fantastic Four (1998) #24',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/31699',
#        'name': 'Last Farewell',
#        'type': 'interiorStory'}],
#      'returned': 20},
#     'events': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009360/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/116',
#        'name': 'Acts of Vengeance!'}],
#      'returned': 1},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/1004/hydro-man?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Hydro-Man?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009360/hydro-man?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/4/f0/4c003ec140c31.jpg'},
#    {'id': 1009361,
#     'name': 'Hyperion (Earth-712)',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009361',
#     'comics': {'available': 35,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009361/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17534',
#        'name': 'Avengers (1998) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17545',
#        'name': 'Avengers (1998) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/7339',
#        'name': 'Avengers (1963) #86'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/6930',
#        'name': 'Avengers Annual (1967) #16'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/1311',
#        'name': 'AVENGERS ASSEMBLE (Hardcover)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20279',
#        'name': 'Defenders (1972) #114'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20181',
#        'name': 'Doctor Strange, Sorcerer Supreme (1988) #21'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/19539',
#        'name': 'Marvel Two-in-One (1974) #67'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10493',
#        'name': 'Paradise X (2002) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10497',
#        'name': 'Paradise X (2002) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10499',
#        'name': 'Paradise X (2002) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10501',
#        'name': 'Paradise X (2002) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10503',
#        'name': 'Paradise X (2002) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10504',
#        'name': 'Paradise X (2002) #9'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10494',
#        'name': 'Paradise X (2002) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10495',
#        'name': 'Paradise X (2002) #11'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15902',
#        'name': 'Paradise X Vol. 1 (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/16209',
#        'name': 'PARADISE X VOL. 2 TPB [NEW PRINTING] (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51113',
#        'name': 'S.H.I.E.L.D. (2014) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/3908',
#        'name': 'Squadron Supreme (2006) #1'}],
#      'returned': 20},
#     'series': {'available': 22,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009361/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/1991',
#        'name': 'Avengers (1963 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/354',
#        'name': 'Avengers (1998 - 2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1988',
#        'name': 'Avengers Annual (1967 - 1994)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1340',
#        'name': 'AVENGERS ASSEMBLE (2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3743',
#        'name': 'Defenders (1972 - 1986)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3741',
#        'name': 'Doctor Strange, Sorcerer Supreme (1988 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3715',
#        'name': 'Marvel Two-in-One (1974 - 1983)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2059',
#        'name': 'Paradise X (2002 - 2003)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2431',
#        'name': 'Paradise X Vol. 1 (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2702',
#        'name': 'PARADISE X VOL. 2 TPB [NEW PRINTING] (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/19639',
#        'name': 'S.H.I.E.L.D. (2014 - 2015)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/944',
#        'name': 'Squadron Supreme (2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1791',
#        'name': 'SQUADRON SUPREME : THE PRE-WAR YEARS (2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3684',
#        'name': 'Squadron Supreme: Death of a Universe Graphic Novel (1989)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/25440',
#        'name': 'SQUADRON SUPREME: HYPERION VS. NIGHTHAWK (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1136',
#        'name': 'Squadron Supreme: Hyperion Vs. Nighthawk (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3685',
#        'name': 'Squadron Supreme: New World Order (1999)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/942',
#        'name': 'Supreme Power: Hyperion (2005 - 2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2083',
#        'name': 'Thor (1966 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/18527',
#        'name': 'Thunderbolts (2006 - 2012)'}],
#      'returned': 20},
#     'stories': {'available': 38,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009361/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3918',
#        'name': 'THUNDERBOLTS (2006) #107',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5227',
#        'name': '1 of 5 - 5XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5235',
#        'name': '5 of 5 - 5XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5249',
#        'name': '1 of 6 - The Pre-War Years',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/5251',
#        'name': '2 of 6 - The Pre-War Years',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/6184',
#        'name': 'ULTIMATE POWER (2006) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/6190',
#        'name': 'Cover #6190',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/6236',
#        'name': '1 of 4 - 4 XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/7900',
#        'name': '2 of 4 - 4 XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/7902',
#        'name': '3 of 4 - 4XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/8355',
#        'name': '4 of 4 - 4XLS',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/15241',
#        'name': 'Brain-Child to the Dark Tower Came',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/16841',
#        'name': 'Thor (1966) #280',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/17388',
#        'name': 'Avengers Annual (1967) #16',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26017',
#        'name': 'Cover #26017',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26018',
#        'name': 'Paradise X Issue 1',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26020',
#        'name': 'Paradise X Issue 10',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26021',
#        'name': 'Cover #26021',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26022',
#        'name': 'Paradise X Issue 11',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26026',
#        'name': 'Paradise X Issue 2',
#        'type': 'interiorStory'}],
#      'returned': 20},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009361/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/1007/hyperion?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Hyperion%20(Earth-712)?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009361/hyperion_earth-712?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg'},
#    {'id': 1011246,
#     'name': 'Hypno-Hustler',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/f0/4c002ef943bbf',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011246',
#     'comics': {'available': 3,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011246/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30320',
#        'name': 'Amazing Spider-Man (1999) #645'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/35880',
#        'name': 'Amazing Spider-Man (1999) #645 (SPIDEY VS. VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/5763',
#        'name': 'Spider-Man: Reign (2006) #2'}],
#      'returned': 3},
#     'series': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011246/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/454',
#        'name': 'Amazing Spider-Man (1999 - 2013)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/852',
#        'name': 'Spider-Man: Reign (2006 - 2007)'}],
#      'returned': 2},
#     'stories': {'available': 4,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011246/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/4434',
#        'name': 'Spider-Man: Reign (2006) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/4435',
#        'name': '2 of 4 - Reign - 4XLS',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/69466',
#        'name': 'Amazing Spider-Man (1999) #645',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/94765',
#        'name': 'Amazing Spider-Man (1999) #645, SPIDEY VS. VARIANT',
#        'type': 'cover'}],
#      'returned': 4},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011246/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/1010/hypno-hustler?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Hypno-Hustler?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011246/hypno-hustler?utm_campaign=apiRef&utm_source=b4a6f1c2c9bc393ac9875f7930c8e5f6'}],
#     'picture_url': 'http://i.annihil.us/u/prod/marvel/i/mg/b/f0/4c002ef943bbf.jpg'}]}}

# %%
nombre = "Hugo_Marvel" + ".csv"  
        
df_characters.to_csv(nombre, index=False)

# %%
marvel = pd.read_csv("Hugo_Marvel.csv")
marvel
# Out:
#          id                        name  \
# 0   1011400                H.A.M.M.E.R.
# 1   1009332                H.E.R.B.I.E.
# 2   1011391                    Hairball
# 3   1009333  Half-Life (Tony Masterson)
# 4   1009334                  Hammerhead
# ..      ...                         ...
# 69  1009358                      Hussar
# 70  1009359                       Hydra
# 71  1009360                   Hydro-Man
# 72  1009361        Hyperion (Earth-712)
# 73  1011246               Hypno-Hustler
#
#                                           picture_url
# 0   http://i.annihil.us/u/prod/marvel/i/mg/6/c0/4c...
# 1   http://i.annihil.us/u/prod/marvel/i/mg/c/e0/4c...
# 2   http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...
# 3   http://i.annihil.us/u/prod/marvel/i/mg/a/20/4c...
# 4   http://i.annihil.us/u/prod/marvel/i/mg/5/c0/4c...
# ..                                                ...
# 69  http://i.annihil.us/u/prod/marvel/i/mg/2/e0/4c...
# 70  http://i.annihil.us/u/prod/marvel/i/mg/8/40/4c...
# 71  http://i.annihil.us/u/prod/marvel/i/mg/4/f0/4c...
# 72  http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...
# 73  http://i.annihil.us/u/prod/marvel/i/mg/b/f0/4c...
#
# [74 rows x 3 columns]
