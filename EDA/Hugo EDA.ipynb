# %% [markdown]
# ![imagen](./img/guj36aqa.png)

# %% [markdown]
# # AGRESIONES LGTBIFÓBICAS EN ESPAÑA.
# ## Evolución y análisis de subgrupos.

# %% [markdown]
# ### TEMA

# %% [markdown]
# Este proyecto tiene como objetivo llevar a cabo un análisis exhaustivo de los delitos de odio registrados en España desde 2014 hasta 2023, segmentado por comunidades autónomas. La meta es identificar tendencias, patrones y variaciones en la incidencia de estos delitos a lo largo del tiempo y en diferentes regiones del país. Además, se buscará enriquecer el análisis con un dataset que incluya diversas identidades y realidades del colectivo LGTBIQ+.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# HIPÓTESIS PRINCIPAL: El aumento de las agresiones al colectivo LGTBIQ+ en el estado español.

# %% [markdown]
# SUB-HIPÓTESIS:
#
# - Incremento de Delitos de Odio: Se hipotetiza que ha habido un aumento significativo en la cantidad de delitos de odio en España entre 2014 y 2023.
#
# - Variabilidad por Comunidades Autónomas: Se plantea la hipótesis de que existen diferencias notables en la incidencia de delitos de odio entre comunidades autónomas. Confirmar o desmentir los sesgos centralistas vs. sesgos provinciales.
# - Identificación de Subgrupos Vulnerables: Se sugiere que dentro del colectivo LGTBIQ+, ciertos subgrupos (como personas trans, no binarias, bisexuales, asexuales) son más propensos a sufrir delitos de odio, lo que resalta la necesidad de un análisis detallado sobre las realidades y experiencias específicas de estos grupos.
#
# - Impacto de la Legislación: Se plantea la hipótesis de que la implementación de políticas públicas y leyes contra la discriminación en ciertas comunidades autónomas está asociada con una disminución de los delitos de odio en esas áreas, sugiriendo que las medidas legislativas pueden ser efectivas en la reducción de la violencia. También el análisis de los años en los que ha habido elecciones estatales y autonómicas con fuertes impactos.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# **PRIMER DATASET**
# Para obtener información sobre los registros de agresiones racistas y LGTBIfóbicas. Portal estadístico de criminalidad.
# - Hechos conocidos por causa delitos de odio por CC.AA. desde el 2014 hasta el 2024.
#
#
# **SEGUNDO DATASET**
# Más detalle y variedad en clasificaicón de agresions LGTBIfóbicas.
# - Informe de incidentes de odio motivados por LGTBIfobia. Intención de conseguir un csv o scrappear los datos: Completar los datos con modalidades e identidades. (Varios años)
# (https://contraelodio.org/wp/informe-lgtbifobia-madrid/)
#
# **TERCER DATASET**
# Barómetro para comparar las agresiones de España con el resto de Europa.
# - Special Eurobarometer 493: Discrimination in the EU (including LGBTI) (https://data.europa.eu/data/datasets/s2251_91_4_493_eng?locale=en)
#
# **CUARTO DATASET**
# Recurso sobre legislación en materia LGTBIQ+ en el mundo.
# - Sexual Orientation Laws | EDA
# (https://www.kaggle.com/code/chaitanya99/sexual-orientation-laws-eda/report)
#
# **QUINTO DATASET**
# Legislación en materia LGTBIQ+ en el estado español.
# - ILGA dataset, Spain LGTBI (https://database.ilga.org/spain-lgbti)

# %%
import pandas as pd
totalestatal = pd.read_csv("data/EDACC.AA._14-23.csv")
totalestatal
# data2 = pd.read_csv("data/omophobia.csv")
# Out:
#     AÑO  TOTAL NACIONAL  ANDALUCÍA  ARAGÓN  ASTURIAS (PRINCIPADO DE)  \
# 0  2023             530         80      15                        10
# 1  2022             464         68       9                         9
# 2  2021             477         64      13                        10
# 3  2020             282         36       3                         1
# 4  2019             283         42       2                         6
# 5  2018             259         36       6                         5
# 6  2017             271         18       3                         2
# 7  2016             230         30       5                         1
# 8  2015             169         15       4                         1
# 9  2014             513        188      36                        15
#
#    BALEARS (ILLES)  CANARIAS  CANTABRIA  CASTILLA Y LEÓN  \
# 0                9        35          2               28
# 1                2        18          6               15
# 2               10        15          4               18
# 3                5        14          1                8
# 4                1        14          1               16
# 5                6         5          1                5
# 6                1        17          0                7
# 7                4         2          3                4
# 8                4         6          2                5
# 9               41        16          0               19
#
#    CASTILLA - LA MANCHA  ...  GALICIA  MADRID (COMUNIDAD DE)  \
# 0                    12  ...       24                     71
# 1                    20  ...       11                     51
# 2                     7  ...       23                     75
# 3                     7  ...        5                     42
# 4                     5  ...       12                     42
# 5                     7  ...       10                     42
# 6                     6  ...        6                     39
# 7                     4  ...       10                     42
# 8                     6  ...        4                     19
# 9                    15  ...       43                     26
#
#    MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  PAÍS VASCO  RIOJA (LA)  \
# 0                  11                             6          37           2
# 1                  10                             8          88           0
# 2                   7                             4          65           0
# 3                   4                             4          45           0
# 4                   3                             0          12           0
# 5                   4                             1          34           1
# 6                   5                             5          30           0
# 7                   2                            10          30           0
# 8                   4                             5          27           0
# 9                  11                             9          14           0
#
#    CIUDAD AUTÓNOMA DE CEUTA  CIUDAD AUTÓNOMA DE MELILLA  EN EL EXTRANJERO  \
# 0                         1                           2                 1
# 1                         0                           1                 0
# 2                         0                           2                 0
# 3                         0                           7                 0
# 4                         0                           1                 1
# 5                         0                           2                 1
# 6                         0                           1                 1
# 7                         0                           3                 0
# 8                         0                           0                 0
# 9                         2                           2                 2
#
#    DESCONOCIDO
# 0            0
# 1            0
# 2            1
# 3            0
# 4            1
# 5            0
# 6            0
# 7            0
# 8            0
# 9            0
#
# [10 rows x 23 columns]

# %%
# mundial = pd.read_csv("data/omophobia.csv", delimiter = ";", encoding='latin-1')
# mundial

# %% [markdown]
# CSVs redactados a mano:
# 1. Organización de agresiones por identidad
# 2. Organización de agresiones por sexualidad

# %%
id2021 = pd.read_csv("data/identidad2021.csv")
id2022 = pd.read_csv("data/identidad2022.csv")
id2023 = pd.read_csv("data/identidad2023.csv")
or2021 = pd.read_csv("data/orientacion2021.csv")
or2022 = pd.read_csv("data/orientacion2022.csv")
or2023 = pd.read_csv("data/orientacion2023.csv")
display(id2021, id2022, id2023, or2021, or2022, or2023)
# Out:
#   Sexo/Id Sexual o Género  Casos
# 0              Hombre Cis    128
# 1            Hombre Trans      9
# 2               Mujer Cis     21
# 3             Mujer Trans     27
# 4      Persona no binaria      2
# 5                   Total    187
# 6             Desconocido     24
#   Sexo-id sexual/género  Casos
# 0            Hombre Cis    103
# 1          Hombre Trans      5
# 2             Mujer Cis     19
# 3           Mujer Trans     21
# 4    Persona no binaria      4
# 5                 Total    152
# 6           Desconocido     21
#        Sexo/Identidad  Casos
# 0          Hombre Cis     94
# 1        Hombre Trans      9
# 2           Mujer Cis     40
# 3         Mujer Trans     35
# 4  Persona no Binaria      9
# 5            Intersex      1
# 6               Total    188
# 7         Desconocido     50
#     Orientación  Casos
# 0           Gay    125
# 1      Lesbiana     19
# 2      Bisexual      7
# 3  Heterosexual     12
# 4          Otro      1
# 5         Total    164
#     Orientación  Casos
# 0           Gay    112
# 1      Lesbiana     16
# 2      Bisexual      3
# 3  Heterosexual     12
# 4         Total    143
# 5   Desconocido     42
#   Orientación Sexual  Casos
# 0                Gay     83
# 1           Lesbiana     23
# 2           Bisexual     11
# 3       Heterosexual      8
# 4              Total    125
# 5        Desconocido    113

# %% [markdown]
# # PLANIFICACIÓN DEL ANÁLISIS Y ESTRUCTURA

# %% [markdown]
# Empezamos definiendo la estructura del análisis, la cual será, teniendo en cuenta las hipótesis a demostrar:
# 1. Introducción:
# ¿que es crimen de odio, no toxdos estan registrados pq depedne de denuncias.
#
# 2. Evolución por años:
# Comparación con gráficas de la evolución que han tenido las agresiones, comentar cuantas agresiones estatales ha habido por año, indicando cual ha tenido menos, cual más, cual es la media y cual es la tendencia.
#
# 3. Evolución geográfica: Mapas de calor por año para ver la evolución por comunidades autónomas. Tb gráfica con eje X temporal y eje Y comunidades, para ver las evoluciones de cada una. Gráficas tipo quesito o asi para ver. Ranking de las más peligrosas y las menos. Cuales estan por encima de la media y cuales no.
#
# 4. Grupos más vulnerables: Comentar la evolución de las agresiones a x identidades, para intentar ver cual es el colectivo más vulnerable y si alguno ha tenido una tendencia a la baja
#
# 5. Impacto posible de la legislacion en años concreto.
#
# 6. Conclusiones

# %% [markdown]
# ### ¿Qué datos concretos necesitamos extraer y analizar para cada putno?¿Y qué representaciones gráficas proponemos?

# %% [markdown]
# 2. Total estatal 2014-2023. max del total, min del total, media agresiones, tendencia alza o baja?<br>
# Gráficos: grafica total años evolucion.
#
# 3.  Por año: max cada comunidad. min cada comunidad. media de cada comunidad. cuales en 2023 estan por encima de la media. tendencia comparativa de todas<br>
# Gráficos: mapa de calor por cada año. grafica evolucion años/agresiones/cc.aa.(varias lineas en la grafica). quesito con el total hasta 2023 por cc.aa. rankings comparativos 2014 vs. 2023: top 3, min 3 y mediana y cuantas por enmcima o debajo de la media(desviacion tipica).
#
# 4.  Agresiones por colectivo a lo largo de los años, tendencias de cada colectivo.<br>
# Gráficos: otra grafica años/agresiones/colectivos (varias lineas x cada colectivo). ranking 201Xvs2024 de min, max, mediana, desviacion tipica
#
# 5. Observar gráficas de cada año con impacto legislativo del total estatal y de colectivos.
#
# 6. (Conclusiones):<br>
# han aumentado o disminuido en total estatal las agresiones?<br>
# en que cc.aa. hay una tendencia a la baja y en cuales a la alza?<br>
# nucleos metropolitanos vs. zonas despobladas¿donde hay mas? (habrá que relacionar la cantidad de habitantes?)<br>
# que colectivos han sufrido más agresiones (tener en cuenta la visibilidad) cuales han disminuido su probabilidad de sufrir agresiones y cuales han aumentado?<br>
# impactos de la legislacion?

# %% [markdown]
# # TRATAMIENTO DE DATOS Y OBTENCIÓN DE GRÁFICAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## TOTAL ESTATAL

# %%
totalestatal.set_index("AÑO", inplace=True)

# %%
totalestatal
# GRAFICA: grafica con y= agresiones, x= años del total nacional
# Out:
#       TOTAL NACIONAL  ANDALUCÍA  ARAGÓN  ASTURIAS (PRINCIPADO DE)  \
# AÑO
# 2023             530         80      15                        10
# 2022             464         68       9                         9
# 2021             477         64      13                        10
# 2020             282         36       3                         1
# 2019             283         42       2                         6
# 2018             259         36       6                         5
# 2017             271         18       3                         2
# 2016             230         30       5                         1
# 2015             169         15       4                         1
# 2014             513        188      36                        15
#
#       BALEARS (ILLES)  CANARIAS  CANTABRIA  CASTILLA Y LEÓN  \
# AÑO
# 2023                9        35          2               28
# 2022                2        18          6               15
# 2021               10        15          4               18
# 2020                5        14          1                8
# 2019                1        14          1               16
# 2018                6         5          1                5
# 2017                1        17          0                7
# 2016                4         2          3                4
# 2015                4         6          2                5
# 2014               41        16          0               19
#
#       CASTILLA - LA MANCHA  CATALUÑA  ...  GALICIA  MADRID (COMUNIDAD DE)  \
# AÑO                                   ...
# 2023                    12       111  ...       24                     71
# 2022                    20        88  ...       11                     51
# 2021                     7       101  ...       23                     75
# 2020                     7        69  ...        5                     42
# 2019                     5       101  ...       12                     42
# 2018                     7        77  ...       10                     42
# 2017                     6        99  ...        6                     39
# 2016                     4        60  ...       10                     42
# 2015                     6        50  ...        4                     19
# 2014                    15        43  ...       43                     26
#
#       MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  PAÍS VASCO  \
# AÑO
# 2023                  11                             6          37
# 2022                  10                             8          88
# 2021                   7                             4          65
# 2020                   4                             4          45
# 2019                   3                             0          12
# 2018                   4                             1          34
# 2017                   5                             5          30
# 2016                   2                            10          30
# 2015                   4                             5          27
# 2014                  11                             9          14
#
#       RIOJA (LA)  CIUDAD AUTÓNOMA DE CEUTA  CIUDAD AUTÓNOMA DE MELILLA  \
# AÑO
# 2023           2                         1                           2
# 2022           0                         0                           1
# 2021           0                         0                           2
# 2020           0                         0                           7
# 2019           0                         0                           1
# 2018           1                         0                           2
# 2017           0                         0                           1
# 2016           0                         0                           3
# 2015           0                         0                           0
# 2014           0                         2                           2
#
#       EN EL EXTRANJERO  DESCONOCIDO
# AÑO
# 2023                 1            0
# 2022                 0            0
# 2021                 0            1
# 2020                 0            0
# 2019                 1            1
# 2018                 1            0
# 2017                 1            0
# 2016                 0            0
# 2015                 0            0
# 2014                 2            0
#
# [10 rows x 22 columns]

# %%
totalestatal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 2023 to 2014
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   TOTAL NACIONAL                10 non-null     int64
#  1   ANDALUCÍA                     10 non-null     int64
#  2   ARAGÓN                        10 non-null     int64
#  3   ASTURIAS (PRINCIPADO DE)      10 non-null     int64
#  4   BALEARS (ILLES)               10 non-null     int64
#  5   CANARIAS                      10 non-null     int64
#  6   CANTABRIA                     10 non-null     int64
#  7   CASTILLA Y LEÓN               10 non-null     int64
#  8   CASTILLA - LA MANCHA          10 non-null     int64
#  9   CATALUÑA                      10 non-null     int64
#  10  COMUNITAT VALENCIANA          10 non-null     int64
#  11  EXTREMADURA                   10 non-null     int64
#  12  GALICIA                       10 non-null     int64
#  13  MADRID (COMUNIDAD DE)         10 non-null     int64
#  14  MURCIA (REGIÓN DE)            10 non-null     int64
#  15  NAVARRA (COMUNIDAD FORAL DE)  10 non-null     int64
#  16  PAÍS VASCO                    10 non-null     int64
#  17  RIOJA (LA)                    10 non-null     int64
#  18  CIUDAD AUTÓNOMA DE CEUTA      10 non-null     int64
#  19  CIUDAD AUTÓNOMA DE MELILLA    10 non-null     int64
#  20  EN EL EXTRANJERO              10 non-null     int64
#  21  DESCONOCIDO                   10 non-null     int64
# dtypes: int64(22)
# memory usage: 1.8 KB

# %%
totalestatal.describe()
# Out:
#        TOTAL NACIONAL   ANDALUCÍA     ARAGÓN  ASTURIAS (PRINCIPADO DE)  \
# count        10.00000   10.000000  10.000000                 10.000000
# mean        347.80000   57.700000   9.600000                  6.000000
# std         132.84979   50.526231  10.265368                  4.876246
# min         169.00000   15.000000   2.000000                  1.000000
# 25%         262.00000   31.500000   3.250000                  1.250000
# 50%         282.50000   39.000000   5.500000                  5.500000
# 75%         473.75000   67.000000  12.000000                  9.750000
# max         530.00000  188.000000  36.000000                 15.000000
#
#        BALEARS (ILLES)   CANARIAS  CANTABRIA  CASTILLA Y LEÓN  \
# count        10.000000  10.000000  10.000000        10.000000
# mean          8.300000  14.200000   2.000000        12.500000
# std          11.888837   9.186947   1.885618         7.933753
# min           1.000000   2.000000   0.000000         4.000000
# 25%           2.500000   8.000000   1.000000         5.500000
# 50%           4.500000  14.500000   1.500000        11.500000
# 75%           8.250000  16.750000   2.750000        17.500000
# max          41.000000  35.000000   6.000000        28.000000
#
#        CASTILLA - LA MANCHA    CATALUÑA  ...    GALICIA  \
# count             10.000000   10.000000  ...  10.000000
# mean               8.900000   79.900000  ...  14.800000
# std                5.130519   23.727387  ...  12.044362
# min                4.000000   43.000000  ...   4.000000
# 25%                6.000000   62.250000  ...   7.000000
# 50%                7.000000   82.500000  ...  10.500000
# 75%               10.750000  100.500000  ...  20.250000
# max               20.000000  111.000000  ...  43.000000
#
#        MADRID (COMUNIDAD DE)  MURCIA (REGIÓN DE)  \
# count              10.000000           10.000000
# mean               44.900000            6.100000
# std                17.387416            3.414023
# min                19.000000            2.000000
# 25%                39.750000            4.000000
# 50%                42.000000            4.500000
# 75%                48.750000            9.250000
# max                75.000000           11.000000
#
#        NAVARRA (COMUNIDAD FORAL DE)  PAÍS VASCO  RIOJA (LA)  \
# count                     10.000000   10.000000   10.000000
# mean                       5.200000   38.200000    0.300000
# std                        3.224903   23.083424    0.674949
# min                        0.000000   12.000000    0.000000
# 25%                        4.000000   27.750000    0.000000
# 50%                        5.000000   32.000000    0.000000
# 75%                        7.500000   43.000000    0.000000
# max                       10.000000   88.000000    2.000000
#
#        CIUDAD AUTÓNOMA DE CEUTA  CIUDAD AUTÓNOMA DE MELILLA  EN EL EXTRANJERO  \
# count                 10.000000                   10.000000         10.000000
# mean                   0.300000                    2.100000          0.600000
# std                    0.674949                    1.911951          0.699206
# min                    0.000000                    0.000000          0.000000
# 25%                    0.000000                    1.000000          0.000000
# 50%                    0.000000                    2.000000          0.500000
# 75%                    0.000000                    2.000000          1.000000
# max                    2.000000                    7.000000          2.000000
#
#        DESCONOCIDO
# count    10.000000
# mean      0.200000
# std       0.421637
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# Ningún missing value en el DF

# %% [markdown]
# Pasamos obtener los datos necesarios:
# - Agresiones a nivel estatal por año
# - Maximo estatal total
# - Minimo estatal total
# - Media estatal

# %%
totalaños = totalestatal.iloc[:, :1]
totalaños
# GRÁFICA: GRAFICA PARA VER LA EVOLUCIÓN POR AÑOS
# Out:
#       TOTAL NACIONAL
# AÑO
# 2023             530
# 2022             464
# 2021             477
# 2020             282
# 2019             283
# 2018             259
# 2017             271
# 2016             230
# 2015             169
# 2014             513

# %%
# Vemos los años ordenados por peligrosidad
totalaños.sort_values(by = "TOTAL NACIONAL", ascending= False)
# GRÁFICA: DIAGRAMA DE BARRAS PARA VER CUALES SON LOS AÑOS CON MÁS AGRESIONES
# Out:
#       TOTAL NACIONAL
# AÑO
# 2023             530
# 2014             513
# 2021             477
# 2022             464
# 2019             283
# 2020             282
# 2017             271
# 2018             259
# 2016             230
# 2015             169

# %%
print(totalaños.max())
print(totalaños.idxmax())
print(totalaños.min())
print(totalaños.idxmin())
print(round(totalaños.std(), 2))
print((int(round(totalaños["TOTAL NACIONAL"].mean()))))
media_ccaa = (int(round(totalaños["TOTAL NACIONAL"].mean())))/(len(totalestatal.columns)-3)
media_ccaa

# GRÁFICA: TABLA ACOMPAÑANTE DEL AÑO CON MÁS AGRESIONES, DEL AÑO CON MENOS Y VER SI SIRVE PARA ALGO LA D.T.
# Out:
# TOTAL NACIONAL    530
# dtype: int64
# TOTAL NACIONAL    2023
# dtype: int64
# TOTAL NACIONAL    169
# dtype: int64
# TOTAL NACIONAL    2015
# dtype: int64
# TOTAL NACIONAL    132.85
# dtype: float64
# 348
# 18.31578947368421

# %% [markdown]
# El año con más agresiones fue 2023 con 530.
# El año con menos agresiones fue 2015 con 169.
# La media anual de agresiones es 348.
# La desviación típica es 132.85
# La media anual por cc.aa. es 18.32

# %% [markdown]
# ## POR CC.AA.

# %% [markdown]
# Por año: media de cada comunidad, media automonica anual.<br>cuales en 2023 estan por encima de la media. <br>tendencia comparativa de todas<br>
# Gráficos: mapa de calor por cada año. grafica evolucion años/agresiones/cc.aa.(varias lineas en la grafica). quesito con el total hasta 2023 por cc.aa. rankings comparativos 2014 vs. 2023: top 3, min 3 y mediana y cuantas por enmcima o debajo de la media(desviacion tipica).

# %%
# GRAFICA: grafica con y= agresiones, x= años y varias lineas por cc.aa.

# %%
totalestatal
# Out:
#       TOTAL NACIONAL  ANDALUCÍA  ARAGÓN  ASTURIAS (PRINCIPADO DE)  \
# AÑO
# 2023             530         80      15                        10
# 2022             464         68       9                         9
# 2021             477         64      13                        10
# 2020             282         36       3                         1
# 2019             283         42       2                         6
# 2018             259         36       6                         5
# 2017             271         18       3                         2
# 2016             230         30       5                         1
# 2015             169         15       4                         1
# 2014             513        188      36                        15
#
#       BALEARS (ILLES)  CANARIAS  CANTABRIA  CASTILLA Y LEÓN  \
# AÑO
# 2023                9        35          2               28
# 2022                2        18          6               15
# 2021               10        15          4               18
# 2020                5        14          1                8
# 2019                1        14          1               16
# 2018                6         5          1                5
# 2017                1        17          0                7
# 2016                4         2          3                4
# 2015                4         6          2                5
# 2014               41        16          0               19
#
#       CASTILLA - LA MANCHA  CATALUÑA  ...  GALICIA  MADRID (COMUNIDAD DE)  \
# AÑO                                   ...
# 2023                    12       111  ...       24                     71
# 2022                    20        88  ...       11                     51
# 2021                     7       101  ...       23                     75
# 2020                     7        69  ...        5                     42
# 2019                     5       101  ...       12                     42
# 2018                     7        77  ...       10                     42
# 2017                     6        99  ...        6                     39
# 2016                     4        60  ...       10                     42
# 2015                     6        50  ...        4                     19
# 2014                    15        43  ...       43                     26
#
#       MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  PAÍS VASCO  \
# AÑO
# 2023                  11                             6          37
# 2022                  10                             8          88
# 2021                   7                             4          65
# 2020                   4                             4          45
# 2019                   3                             0          12
# 2018                   4                             1          34
# 2017                   5                             5          30
# 2016                   2                            10          30
# 2015                   4                             5          27
# 2014                  11                             9          14
#
#       RIOJA (LA)  CIUDAD AUTÓNOMA DE CEUTA  CIUDAD AUTÓNOMA DE MELILLA  \
# AÑO
# 2023           2                         1                           2
# 2022           0                         0                           1
# 2021           0                         0                           2
# 2020           0                         0                           7
# 2019           0                         0                           1
# 2018           1                         0                           2
# 2017           0                         0                           1
# 2016           0                         0                           3
# 2015           0                         0                           0
# 2014           0                         2                           2
#
#       EN EL EXTRANJERO  DESCONOCIDO
# AÑO
# 2023                 1            0
# 2022                 0            0
# 2021                 0            1
# 2020                 0            0
# 2019                 1            1
# 2018                 1            0
# 2017                 1            0
# 2016                 0            0
# 2015                 0            0
# 2014                 2            0
#
# [10 rows x 22 columns]

# %%
totalccaa = totalestatal.drop(totalestatal.columns[[0,0]], axis=1)
totalccaa
# Out:
#       ANDALUCÍA  ARAGÓN  ASTURIAS (PRINCIPADO DE)  BALEARS (ILLES)  CANARIAS  \
# AÑO
# 2023         80      15                        10                9        35
# 2022         68       9                         9                2        18
# 2021         64      13                        10               10        15
# 2020         36       3                         1                5        14
# 2019         42       2                         6                1        14
# 2018         36       6                         5                6         5
# 2017         18       3                         2                1        17
# 2016         30       5                         1                4         2
# 2015         15       4                         1                4         6
# 2014        188      36                        15               41        16
#
#       CANTABRIA  CASTILLA Y LEÓN  CASTILLA - LA MANCHA  CATALUÑA  \
# AÑO
# 2023          2               28                    12       111
# 2022          6               15                    20        88
# 2021          4               18                     7       101
# 2020          1                8                     7        69
# 2019          1               16                     5       101
# 2018          1                5                     7        77
# 2017          0                7                     6        99
# 2016          3                4                     4        60
# 2015          2                5                     6        50
# 2014          0               19                    15        43
#
#       COMUNITAT VALENCIANA  ...  GALICIA  MADRID (COMUNIDAD DE)  \
# AÑO                         ...
# 2023                    70  ...       24                     71
# 2022                    55  ...       11                     51
# 2021                    53  ...       23                     75
# 2020                    21  ...        5                     42
# 2019                    18  ...       12                     42
# 2018                    13  ...       10                     42
# 2017                    26  ...        6                     39
# 2016                    17  ...       10                     42
# 2015                    17  ...        4                     19
# 2014                    28  ...       43                     26
#
#       MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  PAÍS VASCO  \
# AÑO
# 2023                  11                             6          37
# 2022                  10                             8          88
# 2021                   7                             4          65
# 2020                   4                             4          45
# 2019                   3                             0          12
# 2018                   4                             1          34
# 2017                   5                             5          30
# 2016                   2                            10          30
# 2015                   4                             5          27
# 2014                  11                             9          14
#
#       RIOJA (LA)  CIUDAD AUTÓNOMA DE CEUTA  CIUDAD AUTÓNOMA DE MELILLA  \
# AÑO
# 2023           2                         1                           2
# 2022           0                         0                           1
# 2021           0                         0                           2
# 2020           0                         0                           7
# 2019           0                         0                           1
# 2018           1                         0                           2
# 2017           0                         0                           1
# 2016           0                         0                           3
# 2015           0                         0                           0
# 2014           0                         2                           2
#
#       EN EL EXTRANJERO  DESCONOCIDO
# AÑO
# 2023                 1            0
# 2022                 0            0
# 2021                 0            1
# 2020                 0            0
# 2019                 1            1
# 2018                 1            0
# 2017                 1            0
# 2016                 0            0
# 2015                 0            0
# 2014                 2            0
#
# [10 rows x 21 columns]

# %%
# Crear la figura y el eje
fig, ax = plt.subplots()

# Graficar cada columna (CCAA) como una línea
for column in totalccaa.columns:
    ax.plot(totalccaa.index, totalccaa[column], label=column)

# Añadir etiquetas y título
ax.set_ylim(0,120)
ax.set_xticks(totalccaa.index)  # Esto asegura que se usen los años del índice como etiquetas
ax.set_xticklabels(totalccaa.index)
ax.set_xlabel('Año')
ax.set_ylabel('Número de Agresiones')
ax.set_title('Agresiones LGTBI por CCAA a lo largo de los años')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Mostrar el gráfico
plt.show()

# %%
round(media_ccaa,2)
# Out:
# 18.32

# %%
mediastotales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 mediastotales
#
# NameError: name 'mediastotales' is not defined

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd

# Configura la ruta de tu ChromeDriver
chrome_driver_path = './chromedriver.exe'  # Reemplaza con la ruta a tu ChromeDriver
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)

# URL de la página de Wikipedia
url = "https://es.wikipedia.org/wiki/Anexo:Comunidades_y_ciudades_aut%C3%B3nomas_de_Espa%C3%B1a"

# Abrir la página
driver.get(url)

# Esperar un momento para que la página cargue
time.sleep(2)

# Encontrar la tabla que contiene los datos
tabla = driver.find_element(By.CLASS_NAME, 'wikitable')

# Crear un diccionario para almacenar las comunidades y poblaciones
datos = {}

# Recorrer las filas de la tabla
filas = tabla.find_elements(By.TAG_NAME, 'tr')[1:]  # Omitir la primera fila (encabezados)
for fila in filas:
    columnas = fila.find_elements(By.TAG_NAME, 'td')
    if len(columnas) > 4:  # Asegurarse de que la fila tiene suficientes columnas
        comunidad = columnas[0].text.strip()  # Nombre de la comunidad
        poblacion = columnas[3].text.strip().replace('.', '').replace(',', '').replace(' ', '')  # Limpiar la población
        try:
            # Intentar convertir la población a entero y agregar al diccionario
            datos[comunidad] = int(poblacion)
        except ValueError:
            # Si no es un número válido, ignorarlo
            print(f"Valor inválido encontrado para {comunidad}: {poblacion}")

# Cerrar el navegador
driver.quit()

# Crear un DataFrame con los datos
densidad = pd.DataFrame(columns=datos.keys())  # Usar las claves del diccionario como columnas
densidad.loc[0] = datos.values()  # Asignar los valores a la primera fila

# Mostrar el DataFrame resultante
densidad
# Out:
#          1        2        3        4        5        6        7        8  \
# 0  8584147  7901963  6871903  5216195  2699424  2383703  2216302  2213016
#
#          9       10       11       12       13       14      15      16  \
# 0  2084086  1551692  1341289  1209906  1054306  1006060  672155  588387
#
#        17     18     19     TOTAL
# 0  322282  85493  83052  48085361

# %%
densidad.to_csv('densidad.csv', index=True)

# %%
densidadordenada = [48085361,8584147,1341289,1006060,1209906,2213016,588387,2383703,2084086,7901963,5216195,1054306,2699424,6871903,1551692,672155,2216302,322282,83052,85493]
densidadordenada = pd.DataFrame(densidadordenada).T
densidadordenada
# Out:
#          0        1        2        3        4        5       6        7   \
# 0  48085361  8584147  1341289  1006060  1209906  2213016  588387  2383703
#
#         8        9        10       11       12       13       14      15  \
# 0  2084086  7901963  5216195  1054306  2699424  6871903  1551692  672155
#
#         16      17     18     19
# 0  2216302  322282  83052  85493

# %%
densidadordenada.columns = estataldensidad.columns
densidadordenada
# Out:
#    TOTAL NACIONAL  ANDALUCÍA   ARAGÓN  ASTURIAS (PRINCIPADO DE)  \
# 0        48085361    8584147  1341289                   1006060
#
#    BALEARS (ILLES)  CANARIAS  CANTABRIA  CASTILLA Y LEÓN  \
# 0          1209906   2213016     588387          2383703
#
#    CASTILLA - LA MANCHA  CATALUÑA  COMUNITAT VALENCIANA  EXTREMADURA  GALICIA  \
# 0               2084086   7901963               5216195      1054306  2699424
#
#    MADRID (COMUNIDAD DE)  MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  \
# 0                6871903             1551692                        672155
#
#    PAÍS VASCO  RIOJA (LA)  CIUDAD AUTÓNOMA DE CEUTA  \
# 0     2216302      322282                     83052
#
#    CIUDAD AUTÓNOMA DE MELILLA
# 0                       85493

# %%
# INCIDENCIA POR AÑO. 2022
estataldensidad = totalestatal.iloc[:, :-2][:1]
densidad23 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad23 = densidad23.iloc[:,1:].T
densidad23.rename(columns={0: 'Casos 2023', 1: 'Población 2023'}, inplace=True)
densidad23["Incidencia por millón"] = (densidad23["Casos 2023"] / densidad23["Población 2023"]) * 1000000
# densidad23 = densidad23.sort_values(by = "Incidencia por millón", ascending= False)
densidad23
# Out:
#                               Casos 2023  Población 2023  \
# ANDALUCÍA                             80         8584147
# ARAGÓN                                15         1341289
# ASTURIAS (PRINCIPADO DE)              10         1006060
# BALEARS (ILLES)                        9         1209906
# CANARIAS                              35         2213016
# CANTABRIA                              2          588387
# CASTILLA Y LEÓN                       28         2383703
# CASTILLA - LA MANCHA                  12         2084086
# CATALUÑA                             111         7901963
# COMUNITAT VALENCIANA                  70         5216195
# EXTREMADURA                            3         1054306
# GALICIA                               24         2699424
# MADRID (COMUNIDAD DE)                 71         6871903
# MURCIA (REGIÓN DE)                    11         1551692
# NAVARRA (COMUNIDAD FORAL DE)           6          672155
# PAÍS VASCO                            37         2216302
# RIOJA (LA)                             2          322282
# CIUDAD AUTÓNOMA DE CEUTA               1           83052
# CIUDAD AUTÓNOMA DE MELILLA             2           85493
#
#                               Incidencia por millón
# ANDALUCÍA                                  9.319505
# ARAGÓN                                    11.183272
# ASTURIAS (PRINCIPADO DE)                   9.939765
# BALEARS (ILLES)                            7.438594
# CANARIAS                                  15.815521
# CANTABRIA                                  3.399123
# CASTILLA Y LEÓN                           11.746430
# CASTILLA - LA MANCHA                       5.757920
# CATALUÑA                                  14.047142
# COMUNITAT VALENCIANA                      13.419744
# EXTREMADURA                                2.845474
# GALICIA                                    8.890786
# MADRID (COMUNIDAD DE)                     10.331927
# MURCIA (REGIÓN DE)                         7.089036
# NAVARRA (COMUNIDAD FORAL DE)               8.926512
# PAÍS VASCO                                16.694476
# RIOJA (LA)                                 6.205745
# CIUDAD AUTÓNOMA DE CEUTA                  12.040649
# CIUDAD AUTÓNOMA DE MELILLA                23.393728

# %%
# INCIDENCIA POR AÑOs. 
# 2023
estataldensidad = totalestatal.iloc[:, :-2][:1]
densidad23 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad23 = densidad23.iloc[:,1:].T
densidad23.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad23["Incidencia por millón 2023"] = (densidad23["Casos"] / densidad23["Población"]) * 1000000
densidad23 = densidad23.iloc[:,2:]
# densidad23 = densidad23.sort_values(by = "Incidencia por millón 2023", ascending= False)
densidad
# Out:
#          1        2        3        4        5        6        7        8  \
# 0  8584147  7901963  6871903  5216195  2699424  2383703  2216302  2213016
#
#          9       10       11       12       13       14      15      16  \
# 0  2084086  1551692  1341289  1209906  1054306  1006060  672155  588387
#
#        17     18     19     TOTAL
# 0  322282  85493  83052  48085361

# %%
# 2022
estataldensidad = totalestatal.iloc[:, :-2][1:2]
densidad22 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad22 = densidad22.iloc[:,1:].T
densidad22.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad22["Incidencia por millón 2022"] = (densidad22["Casos"] / densidad22["Población"]) * 1000000
densidad22 = densidad22.iloc[:,2:]
densidad22
# Out:
#                               Incidencia por millón 2022
# ANDALUCÍA                                       7.921579
# ARAGÓN                                          6.709963
# ASTURIAS (PRINCIPADO DE)                        8.945789
# BALEARS (ILLES)                                 1.653021
# CANARIAS                                        8.133696
# CANTABRIA                                      10.197370
# CASTILLA Y LEÓN                                 6.292730
# CASTILLA - LA MANCHA                            9.596533
# CATALUÑA                                       11.136473
# COMUNITAT VALENCIANA                           10.544084
# EXTREMADURA                                     4.742456
# GALICIA                                         4.074943
# MADRID (COMUNIDAD DE)                           7.421525
# MURCIA (REGIÓN DE)                              6.444578
# NAVARRA (COMUNIDAD FORAL DE)                   11.902017
# PAÍS VASCO                                     39.705780
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     11.696864

# %%
# 2021
estataldensidad = totalestatal.iloc[:, :-2][2:3]
densidad21 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad21 = densidad21.iloc[:,1:].T
densidad21.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad21["Incidencia por millón 2021"] = (densidad21["Casos"] / densidad21["Población"]) * 1000000
densidad21 = densidad21.iloc[:,2:]
densidad21
# Out:
#                               Incidencia por millón 2021
# ANDALUCÍA                                       7.455604
# ARAGÓN                                          9.692169
# ASTURIAS (PRINCIPADO DE)                        9.939765
# BALEARS (ILLES)                                 8.265105
# CANARIAS                                        6.778080
# CANTABRIA                                       6.798247
# CASTILLA Y LEÓN                                 7.551276
# CASTILLA - LA MANCHA                            3.358787
# CATALUÑA                                       12.781634
# COMUNITAT VALENCIANA                           10.160663
# EXTREMADURA                                     4.742456
# GALICIA                                         8.520336
# MADRID (COMUNIDAD DE)                          10.914007
# MURCIA (REGIÓN DE)                              4.511205
# NAVARRA (COMUNIDAD FORAL DE)                    5.951008
# PAÍS VASCO                                     29.328133
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     23.393728

# %%
# 2020
estataldensidad = totalestatal.iloc[:, :-2][3:4]
densidad20 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad20 = densidad20.iloc[:,1:].T
densidad20.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad20["Incidencia por millón 2020"] = (densidad20["Casos"] / densidad20["Población"]) * 1000000
densidad20 = densidad20.iloc[:,2:]
densidad20
# Out:
#                               Incidencia por millón 2020
# ANDALUCÍA                                       4.193777
# ARAGÓN                                          2.236654
# ASTURIAS (PRINCIPADO DE)                        0.993977
# BALEARS (ILLES)                                 4.132552
# CANARIAS                                        6.326208
# CANTABRIA                                       1.699562
# CASTILLA Y LEÓN                                 3.356123
# CASTILLA - LA MANCHA                            3.358787
# CATALUÑA                                        8.732007
# COMUNITAT VALENCIANA                            4.025923
# EXTREMADURA                                     9.484912
# GALICIA                                         1.852247
# MADRID (COMUNIDAD DE)                           6.111844
# MURCIA (REGIÓN DE)                              2.577831
# NAVARRA (COMUNIDAD FORAL DE)                    5.951008
# PAÍS VASCO                                     20.304092
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     81.878048

# %%
# 2019
estataldensidad = totalestatal.iloc[:, :-2][4:5]
densidad19 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad19 = densidad19.iloc[:,1:].T
densidad19.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad19["Incidencia por millón 2019"] = (densidad19["Casos"] / densidad19["Población"]) * 1000000
densidad19 = densidad19.iloc[:,2:]
densidad19
# Out:
#                               Incidencia por millón 2019
# ANDALUCÍA                                       4.892740
# ARAGÓN                                          1.491103
# ASTURIAS (PRINCIPADO DE)                        5.963859
# BALEARS (ILLES)                                 0.826510
# CANARIAS                                        6.326208
# CANTABRIA                                       1.699562
# CASTILLA Y LEÓN                                 6.712246
# CASTILLA - LA MANCHA                            2.399133
# CATALUÑA                                       12.781634
# COMUNITAT VALENCIANA                            3.450791
# EXTREMADURA                                     4.742456
# GALICIA                                         4.445393
# MADRID (COMUNIDAD DE)                           6.111844
# MURCIA (REGIÓN DE)                              1.933373
# NAVARRA (COMUNIDAD FORAL DE)                    0.000000
# PAÍS VASCO                                      5.414425
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     11.696864

# %%
# 2018
estataldensidad = totalestatal.iloc[:, :-2][5:6]
densidad18 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad18 = densidad18.iloc[:,1:].T
densidad18.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad18["Incidencia por millón 2018"] = (densidad18["Casos"] / densidad18["Población"]) * 1000000
densidad18 = densidad18.iloc[:,2:]
densidad18
# Out:
#                               Incidencia por millón 2018
# ANDALUCÍA                                       4.193777
# ARAGÓN                                          4.473309
# ASTURIAS (PRINCIPADO DE)                        4.969883
# BALEARS (ILLES)                                 4.959063
# CANARIAS                                        2.259360
# CANTABRIA                                       1.699562
# CASTILLA Y LEÓN                                 2.097577
# CASTILLA - LA MANCHA                            3.358787
# CATALUÑA                                        9.744414
# COMUNITAT VALENCIANA                            2.492238
# EXTREMADURA                                     2.845474
# GALICIA                                         3.704494
# MADRID (COMUNIDAD DE)                           6.111844
# MURCIA (REGIÓN DE)                              2.577831
# NAVARRA (COMUNIDAD FORAL DE)                    1.487752
# PAÍS VASCO                                     15.340870
# RIOJA (LA)                                      3.102873
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     23.393728

# %%
# 2017
estataldensidad = totalestatal.iloc[:, :-2][6:7]
densidad17 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad17 = densidad17.iloc[:,1:].T
densidad17.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad17["Incidencia por millón 2017"] = (densidad17["Casos"] / densidad17["Población"]) * 1000000
densidad17 = densidad17.iloc[:,2:]
densidad17
# Out:
#                               Incidencia por millón 2017
# ANDALUCÍA                                       2.096889
# ARAGÓN                                          2.236654
# ASTURIAS (PRINCIPADO DE)                        1.987953
# BALEARS (ILLES)                                 0.826510
# CANARIAS                                        7.681824
# CANTABRIA                                       0.000000
# CASTILLA Y LEÓN                                 2.936607
# CASTILLA - LA MANCHA                            2.878960
# CATALUÑA                                       12.528532
# COMUNITAT VALENCIANA                            4.984476
# EXTREMADURA                                     4.742456
# GALICIA                                         2.222696
# MADRID (COMUNIDAD DE)                           5.675284
# MURCIA (REGIÓN DE)                              3.222289
# NAVARRA (COMUNIDAD FORAL DE)                    7.438760
# PAÍS VASCO                                     13.536061
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     11.696864

# %%
# 2016
estataldensidad = totalestatal.iloc[:, :-2][7:8]
densidad16 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad16 = densidad16.iloc[:,1:].T
densidad16.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad16["Incidencia por millón 2016"] = (densidad16["Casos"] / densidad16["Población"]) * 1000000
densidad16 = densidad16.iloc[:,2:]
densidad16
# Out:
#                               Incidencia por millón 2016
# ANDALUCÍA                                       3.494814
# ARAGÓN                                          3.727757
# ASTURIAS (PRINCIPADO DE)                        0.993977
# BALEARS (ILLES)                                 3.306042
# CANARIAS                                        0.903744
# CANTABRIA                                       5.098685
# CASTILLA Y LEÓN                                 1.678061
# CASTILLA - LA MANCHA                            1.919307
# CATALUÑA                                        7.593050
# COMUNITAT VALENCIANA                            3.259081
# EXTREMADURA                                     2.845474
# GALICIA                                         3.704494
# MADRID (COMUNIDAD DE)                           6.111844
# MURCIA (REGIÓN DE)                              1.288916
# NAVARRA (COMUNIDAD FORAL DE)                   14.877521
# PAÍS VASCO                                     13.536061
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                     35.090592

# %%
# 2015
estataldensidad = totalestatal.iloc[:, :-2][8:9]
densidad15 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad15 = densidad15.iloc[:,1:].T
densidad15.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad15["Incidencia por millón 2015"] = (densidad15["Casos"] / densidad15["Población"]) * 1000000
densidad15 = densidad15.iloc[:,2:]
densidad15
# Out:
#                               Incidencia por millón 2015
# ANDALUCÍA                                       1.747407
# ARAGÓN                                          2.982206
# ASTURIAS (PRINCIPADO DE)                        0.993977
# BALEARS (ILLES)                                 3.306042
# CANARIAS                                        2.711232
# CANTABRIA                                       3.399123
# CASTILLA Y LEÓN                                 2.097577
# CASTILLA - LA MANCHA                            2.878960
# CATALUÑA                                        6.327542
# COMUNITAT VALENCIANA                            3.259081
# EXTREMADURA                                     0.000000
# GALICIA                                         1.481798
# MADRID (COMUNIDAD DE)                           2.764882
# MURCIA (REGIÓN DE)                              2.577831
# NAVARRA (COMUNIDAD FORAL DE)                    7.438760
# PAÍS VASCO                                     12.182455
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                        0.000000
# CIUDAD AUTÓNOMA DE MELILLA                      0.000000

# %%
# 2014
estataldensidad = totalestatal.iloc[:, :-2][9:10]
densidad14 = pd.concat([estataldensidad,densidadordenada], axis=0, join='outer', ignore_index=True)
densidad14 = densidad14.iloc[:,1:].T
densidad14.rename(columns={0: 'Casos', 1: 'Población'}, inplace=True)
densidad14["Incidencia por millón 2014"] = (densidad14["Casos"] / densidad14["Población"]) * 1000000
densidad14 = densidad14.iloc[:,2:]
densidad14
# Out:
#                               Incidencia por millón 2014
# ANDALUCÍA                                      21.900837
# ARAGÓN                                         26.839853
# ASTURIAS (PRINCIPADO DE)                       14.909648
# BALEARS (ILLES)                                33.886930
# CANARIAS                                        7.229952
# CANTABRIA                                       0.000000
# CASTILLA Y LEÓN                                 7.970792
# CASTILLA - LA MANCHA                            7.197400
# CATALUÑA                                        5.441686
# COMUNITAT VALENCIANA                            5.367897
# EXTREMADURA                                     2.845474
# GALICIA                                        15.929324
# MADRID (COMUNIDAD DE)                           3.783523
# MURCIA (REGIÓN DE)                              7.089036
# NAVARRA (COMUNIDAD FORAL DE)                   13.389769
# PAÍS VASCO                                      6.316829
# RIOJA (LA)                                      0.000000
# CIUDAD AUTÓNOMA DE CEUTA                       24.081298
# CIUDAD AUTÓNOMA DE MELILLA                     23.393728

# %%
incidencia = pd.concat([densidad14,densidad15,densidad16,densidad17,densidad18,densidad19,densidad20,densidad21,densidad22,densidad23], axis = 1)
incidencia["Incidencia por millón media"] = incidencia.mean(axis=1)
# incidencia.to_csv('incidencia.csv', index=True)
# incidencia

# %%
incidencia = pd.read_csv("./data/incidencia.csv")
incidencia
# Out:
#            INCIDENCIA POR MILLÓN       2014       2015       2016       2017  \
# 0                      ANDALUCÍA  21.900837   1.747407   3.494814   2.096889
# 1                         ARAGÓN  26.839853   2.982206   3.727757   2.236654
# 2       ASTURIAS (PRINCIPADO DE)  14.909648   0.993977   0.993977   1.987953
# 3                BALEARS (ILLES)  33.886930   3.306042   3.306042   0.826510
# 4                       CANARIAS   7.229952   2.711232   0.903744   7.681824
# 5                      CANTABRIA   0.000000   3.399123   5.098685   0.000000
# 6                CASTILLA Y LEÓN   7.970792   2.097577   1.678061   2.936607
# 7           CASTILLA - LA MANCHA   7.197400   2.878960   1.919307   2.878960
# 8                       CATALUÑA   5.441686   6.327542   7.593050  12.528532
# 9           COMUNITAT VALENCIANA   5.367897   3.259081   3.259081   4.984476
# 10                   EXTREMADURA   2.845474   0.000000   2.845474   4.742456
# 11                       GALICIA  15.929324   1.481798   3.704494   2.222696
# 12         MADRID (COMUNIDAD DE)   3.783523   2.764882   6.111844   5.675284
# 13            MURCIA (REGIÓN DE)   7.089036   2.577831   1.288916   3.222289
# 14  NAVARRA (COMUNIDAD FORAL DE)  13.389769   7.438760  14.877521   7.438760
# 15                    PAÍS VASCO   6.316829  12.182455  13.536061  13.536061
# 16                    RIOJA (LA)   0.000000   0.000000   0.000000   0.000000
# 17      CIUDAD AUTÓNOMA DE CEUTA  24.081298   0.000000   0.000000   0.000000
# 18    CIUDAD AUTÓNOMA DE MELILLA  23.393728   0.000000  35.090592  11.696864
#
#          2018       2019       2020       2021       2022       2023  \
# 0    2.096889   4.892740   4.193777   7.455604   7.921579   9.319505
# 1    2.236654   1.491103   2.236654   9.692169   6.709963  11.183272
# 2    1.987953   5.963859   0.993977   9.939765   8.945789   9.939765
# 3    0.826510   0.826510   4.132552   8.265105   1.653021   7.438594
# 4    7.681824   6.326208   6.326208   6.778080   8.133696  15.815521
# 5    0.000000   1.699562   1.699562   6.798247  10.197370   3.399123
# 6    2.936607   6.712246   3.356123   7.551276   6.292730  11.746430
# 7    2.878960   2.399133   3.358787   3.358787   9.596533   5.757920
# 8   12.528532  12.781634   8.732007  12.781634  11.136473  14.047142
# 9    4.984476   3.450791   4.025923  10.160663  10.544084  13.419744
# 10   4.742456   4.742456   9.484912   4.742456   4.742456   2.845474
# 11   2.222696   4.445393   1.852247   8.520336   4.074943   8.890786
# 12   5.675284   6.111844   6.111844  10.914007   7.421525  10.331927
# 13   3.222289   1.933373   2.577831   4.511205   6.444578   7.089036
# 14   7.438760   0.000000   5.951008   5.951008  11.902017   8.926512
# 15  13.536061   5.414425  20.304092  29.328133  39.705780  16.694476
# 16   0.000000   0.000000   0.000000   0.000000   0.000000   6.205745
# 17   0.000000   0.000000   0.000000   0.000000   0.000000  12.040649
# 18  11.696864  11.696864  81.878048  23.393728  11.696864  23.393728
#
#         media
# 0    6.512004
# 1    6.933629
# 2    5.665666
# 3    6.446782
# 4    6.958829
# 5    3.229167
# 6    5.327845
# 7    4.222475
# 8   10.389823
# 9    6.345622
# 10   4.173361
# 11   5.334471
# 12   6.490196
# 13   3.995638
# 14   8.331412
# 15  17.055437
# 16   0.620575
# 17   3.612195
# 18  23.393728

# %%
import seaborn as sns
plt.figure(figsize=(10, 4))
sns.boxplot(incidencia["media"],color='deeppink', orient = "h");

# %%
plt.figure(figsize=(15,5))
sns.violinplot(incidencia["media"], color='deeppink', orient = "h");

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=incidencia[incidencia.columns]);

# %%
# Obtenemos la media de cada comunidad por año, para ver cuales son las más peligrosas
# REPRESENTACIÓN: DIAGRAMA DE BARRAS DE MEDIAS POR CC.AA. AÑADIENDO UNA BARRA DE MEDIA AUTONOMICA O UNA LINEA EN MEDIO DE LA MEDIA AUTONOMICA
mediastotales = totalccaa.mean().sort_values(ascending=False)
# mediastotales["Media"] = media_ccaa
mediastotales.sort_values(ascending= False)
# Out:
# CATALUÑA                        79.9
# ANDALUCÍA                       57.7
# MADRID (COMUNIDAD DE)           44.9
# PAÍS VASCO                      38.2
# COMUNITAT VALENCIANA            31.8
# GALICIA                         14.8
# CANARIAS                        14.2
# CASTILLA Y LEÓN                 12.5
# ARAGÓN                           9.6
# CASTILLA - LA MANCHA             8.9
# BALEARS (ILLES)                  8.3
# MURCIA (REGIÓN DE)               6.1
# ASTURIAS (PRINCIPADO DE)         6.0
# NAVARRA (COMUNIDAD FORAL DE)     5.2
# EXTREMADURA                      4.2
# CIUDAD AUTÓNOMA DE MELILLA       2.1
# CANTABRIA                        2.0
# EN EL EXTRANJERO                 0.6
# RIOJA (LA)                       0.3
# CIUDAD AUTÓNOMA DE CEUTA         0.3
# DESCONOCIDO                      0.2
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
mediastotales.plot(kind='bar', color='skyblue')

# Añadir títulos y etiquetas
plt.title('Datos por Comunidad Autónoma')
plt.xlabel('Comunidad Autónoma')
plt.ylabel('Valores')
plt.ylim(0,100)

# Rotar las etiquetas del eje x para mejor legibilidad
plt.xticks(rotation=45, ha='right')

bars = mediastotales.plot(kind='bar', color='skyblue')
for bar in bars.patches:
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posición X
        bar.get_height(),  # Posición Y
        f'{bar.get_height():.1f}',  # Formato del texto
        ha='center',  # Alinear al centro
        va='bottom'   # Colocar encima de la barra
    )

plt.axhline(y=media_ccaa, color='red', linestyle='--', label="Media: 18,32")

plt.legend(title='Leyenda')
# Mostrar el gráfico
plt.tight_layout()  # Ajustar el layout para que no se corten las etiquetas
plt.show()

# %%
# lista = [media_a, media_c,....]
# lista.append(media_ccaa)
# [media_a, media_c,....media_ccaa]

# %%
# Vemos que CC.AA. son más peligrosas teniendo en cuenta la media anual autonómica
# GRÁFICA: (¿EL ANTERIOR?) PARA REPRESENTAR LAS QUE ESTÁN POR ENCIMA DE LA MEDIA
# Molaría hacerlo con la densidad de población
totalestatal.iloc[0]
totalestatal.mean()[ totalestatal.mean()> media_ccaa].sort_values(ascending=False)
# Out:
# TOTAL NACIONAL           347.8
# CATALUÑA                  79.9
# ANDALUCÍA                 57.7
# MADRID (COMUNIDAD DE)     44.9
# PAÍS VASCO                38.2
# COMUNITAT VALENCIANA      31.8
# dtype: float64

# %%
# LA COMPRACIÓN EN 2023
# GRÁFICA. OTRO DIAGRAMA DE BARRAS IGUAL QUE EL ANTERIOR
ccaa2023 = (totalestatal).iloc[0,2:] #Escluimos AÑO y TOTAL
ccaa2023.sort_values(ascending=False)
# Out:
# CATALUÑA                        111
# MADRID (COMUNIDAD DE)            71
# COMUNITAT VALENCIANA             70
# PAÍS VASCO                       37
# CANARIAS                         35
# CASTILLA Y LEÓN                  28
# GALICIA                          24
# ARAGÓN                           15
# CASTILLA - LA MANCHA             12
# MURCIA (REGIÓN DE)               11
# ASTURIAS (PRINCIPADO DE)         10
# BALEARS (ILLES)                   9
# NAVARRA (COMUNIDAD FORAL DE)      6
# EXTREMADURA                       3
# CANTABRIA                         2
# RIOJA (LA)                        2
# CIUDAD AUTÓNOMA DE MELILLA        2
# CIUDAD AUTÓNOMA DE CEUTA          1
# EN EL EXTRANJERO                  1
# DESCONOCIDO                       0
# Name: 2023, dtype: int64

# %%
totalestatal
# Out:
#       TOTAL NACIONAL  ANDALUCÍA  ARAGÓN  ASTURIAS (PRINCIPADO DE)  \
# AÑO
# 2023             530         80      15                        10
# 2022             464         68       9                         9
# 2021             477         64      13                        10
# 2020             282         36       3                         1
# 2019             283         42       2                         6
# 2018             259         36       6                         5
# 2017             271         18       3                         2
# 2016             230         30       5                         1
# 2015             169         15       4                         1
# 2014             513        188      36                        15
#
#       BALEARS (ILLES)  CANARIAS  CANTABRIA  CASTILLA Y LEÓN  \
# AÑO
# 2023                9        35          2               28
# 2022                2        18          6               15
# 2021               10        15          4               18
# 2020                5        14          1                8
# 2019                1        14          1               16
# 2018                6         5          1                5
# 2017                1        17          0                7
# 2016                4         2          3                4
# 2015                4         6          2                5
# 2014               41        16          0               19
#
#       CASTILLA - LA MANCHA  CATALUÑA  ...  GALICIA  MADRID (COMUNIDAD DE)  \
# AÑO                                   ...
# 2023                    12       111  ...       24                     71
# 2022                    20        88  ...       11                     51
# 2021                     7       101  ...       23                     75
# 2020                     7        69  ...        5                     42
# 2019                     5       101  ...       12                     42
# 2018                     7        77  ...       10                     42
# 2017                     6        99  ...        6                     39
# 2016                     4        60  ...       10                     42
# 2015                     6        50  ...        4                     19
# 2014                    15        43  ...       43                     26
#
#       MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  PAÍS VASCO  \
# AÑO
# 2023                  11                             6          37
# 2022                  10                             8          88
# 2021                   7                             4          65
# 2020                   4                             4          45
# 2019                   3                             0          12
# 2018                   4                             1          34
# 2017                   5                             5          30
# 2016                   2                            10          30
# 2015                   4                             5          27
# 2014                  11                             9          14
#
#       RIOJA (LA)  CIUDAD AUTÓNOMA DE CEUTA  CIUDAD AUTÓNOMA DE MELILLA  \
# AÑO
# 2023           2                         1                           2
# 2022           0                         0                           1
# 2021           0                         0                           2
# 2020           0                         0                           7
# 2019           0                         0                           1
# 2018           1                         0                           2
# 2017           0                         0                           1
# 2016           0                         0                           3
# 2015           0                         0                           0
# 2014           0                         2                           2
#
#       EN EL EXTRANJERO  DESCONOCIDO
# AÑO
# 2023                 1            0
# 2022                 0            0
# 2021                 0            1
# 2020                 0            0
# 2019                 1            1
# 2018                 1            0
# 2017                 1            0
# 2016                 0            0
# 2015                 0            0
# 2014                 2            0
#
# [10 rows x 22 columns]

# %%
totalestatal.iloc[0,0:][0:1]
# Out:
# TOTAL NACIONAL    530
# Name: 2023, dtype: int64

# %%
media2023 = round(((totalestatal).iloc[0,0:][0:1]/17),2)
media2023 = media2023[0]
media2023
# Out:
# C:\Users\Alumno Prestamo\AppData\Local\Temp\ipykernel_2468\3047165066.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   media2023 = media2023[0]
# np.float64(31.18)

# %%
plt.figure(figsize=(10, 6))
ccaa2023.plot(kind='bar', color='skyblue')

# Añadir títulos y etiquetas
plt.title('Datos por Comunidad Autónoma en 2023')
plt.xlabel('Comunidad Autónoma')
plt.ylabel('Valores')
plt.ylim(0,150)

# Rotar las etiquetas del eje x para mejor legibilidad
plt.xticks(rotation=45, ha='right')

bars = ccaa2023.plot(kind='bar', color='skyblue')
for bar in bars.patches:
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posición X
        bar.get_height(),  # Posición Y
        f'{bar.get_height():.1f}',  # Formato del texto
        ha='center',  # Alinear al centro
        va='bottom'   # Colocar encima de la barra
    )

plt.axhline(y=media2023, color='red', linestyle='--', label="Media: 31,18")

plt.legend(title='Leyenda')
# Mostrar el gráfico
plt.tight_layout()  # Ajustar el layout para que no se corten las etiquetas
plt.show()

# %%
# RANKING por años de las CC.AA. y sus agresiones
# REPRESENTACIÓN: MAPA DE CALOR ANUAL AÑADIENDO TABLAS DEL TOP 5 Y BOTTOM 5/ HEX DIAGRAM MAP (Raúl)
n=0

while n < len(totalestatal.index):
    print("MÁS PELIGROSAS: ") 
    print (totalestatal.iloc[n,1:].sort_values(ascending=False).head(5))
    print("MÁS SEGURAS: ") 
    print(totalestatal.iloc[n,1:].sort_values(ascending=False).tail(5))
    n += 1
# Out:
# MÁS PELIGROSAS:
# CATALUÑA                 111
# ANDALUCÍA                 80
# MADRID (COMUNIDAD DE)     71
# COMUNITAT VALENCIANA      70
# PAÍS VASCO                37
# Name: 2023, dtype: int64
# MÁS SEGURAS:
# RIOJA (LA)                    2
# CIUDAD AUTÓNOMA DE MELILLA    2
# CIUDAD AUTÓNOMA DE CEUTA      1
# EN EL EXTRANJERO              1
# DESCONOCIDO                   0
# Name: 2023, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 88
# PAÍS VASCO               88
# ANDALUCÍA                68
# COMUNITAT VALENCIANA     55
# MADRID (COMUNIDAD DE)    51
# Name: 2022, dtype: int64
# MÁS SEGURAS:
# CIUDAD AUTÓNOMA DE MELILLA    1
# RIOJA (LA)                    0
# CIUDAD AUTÓNOMA DE CEUTA      0
# EN EL EXTRANJERO              0
# DESCONOCIDO                   0
# Name: 2022, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 101
# MADRID (COMUNIDAD DE)     75
# PAÍS VASCO                65
# ANDALUCÍA                 64
# COMUNITAT VALENCIANA      53
# Name: 2021, dtype: int64
# MÁS SEGURAS:
# CIUDAD AUTÓNOMA DE MELILLA    2
# DESCONOCIDO                   1
# RIOJA (LA)                    0
# CIUDAD AUTÓNOMA DE CEUTA      0
# EN EL EXTRANJERO              0
# Name: 2021, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 69
# PAÍS VASCO               45
# MADRID (COMUNIDAD DE)    42
# ANDALUCÍA                36
# COMUNITAT VALENCIANA     21
# Name: 2020, dtype: int64
# MÁS SEGURAS:
# CANTABRIA                   1
# RIOJA (LA)                  0
# CIUDAD AUTÓNOMA DE CEUTA    0
# EN EL EXTRANJERO            0
# DESCONOCIDO                 0
# Name: 2020, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 101
# MADRID (COMUNIDAD DE)     42
# ANDALUCÍA                 42
# COMUNITAT VALENCIANA      18
# CASTILLA Y LEÓN           16
# Name: 2019, dtype: int64
# MÁS SEGURAS:
# CIUDAD AUTÓNOMA DE MELILLA      1
# DESCONOCIDO                     1
# NAVARRA (COMUNIDAD FORAL DE)    0
# RIOJA (LA)                      0
# CIUDAD AUTÓNOMA DE CEUTA        0
# Name: 2019, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 77
# MADRID (COMUNIDAD DE)    42
# ANDALUCÍA                36
# PAÍS VASCO               34
# COMUNITAT VALENCIANA     13
# Name: 2018, dtype: int64
# MÁS SEGURAS:
# NAVARRA (COMUNIDAD FORAL DE)    1
# RIOJA (LA)                      1
# EN EL EXTRANJERO                1
# CIUDAD AUTÓNOMA DE CEUTA        0
# DESCONOCIDO                     0
# Name: 2018, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 99
# MADRID (COMUNIDAD DE)    39
# PAÍS VASCO               30
# COMUNITAT VALENCIANA     26
# ANDALUCÍA                18
# Name: 2017, dtype: int64
# MÁS SEGURAS:
# CIUDAD AUTÓNOMA DE MELILLA    1
# CANTABRIA                     0
# RIOJA (LA)                    0
# CIUDAD AUTÓNOMA DE CEUTA      0
# DESCONOCIDO                   0
# Name: 2017, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 60
# MADRID (COMUNIDAD DE)    42
# PAÍS VASCO               30
# ANDALUCÍA                30
# COMUNITAT VALENCIANA     17
# Name: 2016, dtype: int64
# MÁS SEGURAS:
# ASTURIAS (PRINCIPADO DE)    1
# RIOJA (LA)                  0
# CIUDAD AUTÓNOMA DE CEUTA    0
# EN EL EXTRANJERO            0
# DESCONOCIDO                 0
# Name: 2016, dtype: int64
# MÁS PELIGROSAS:
# CATALUÑA                 50
# PAÍS VASCO               27
# MADRID (COMUNIDAD DE)    19
# COMUNITAT VALENCIANA     17
# ANDALUCÍA                15
# Name: 2015, dtype: int64
# MÁS SEGURAS:
# RIOJA (LA)                    0
# CIUDAD AUTÓNOMA DE CEUTA      0
# CIUDAD AUTÓNOMA DE MELILLA    0
# EN EL EXTRANJERO              0
# DESCONOCIDO                   0
# Name: 2015, dtype: int64
# MÁS PELIGROSAS:
# ANDALUCÍA          188
# GALICIA             43
# CATALUÑA            43
# BALEARS (ILLES)     41
# ARAGÓN              36
# Name: 2014, dtype: int64
# MÁS SEGURAS:
# CIUDAD AUTÓNOMA DE CEUTA      2
# CIUDAD AUTÓNOMA DE MELILLA    2
# CANTABRIA                     0
# RIOJA (LA)                    0
# DESCONOCIDO                   0
# Name: 2014, dtype: int64

# %% [markdown]
# ## ORIENTACION E IDENTIDAD 2021

# %%
# GRÁFICA: STACKED AREA CHART

# %%
id2021
# Out:
#   Sexo/Id Sexual o Género  Casos
# 0              Hombre Cis    128
# 1            Hombre Trans      9
# 2               Mujer Cis     21
# 3             Mujer Trans     27
# 4      Persona no binaria      2
# 5                   Total    187
# 6             Desconocido     24

# %%
id2021
id2021.set_index("Sexo/Id Sexual o Género", inplace= True)
id2021.rename(columns = {"Casos" : "2021"}, inplace = True)

# %%
id2021.T
# Out:
# Sexo/Id Sexual o Género  Hombre Cis  Hombre Trans  Mujer Cis  Mujer Trans  \
# 2021                            128             9         21           27
#
# Sexo/Id Sexual o Género  Persona no binaria  Total  Desconocido
# 2021                                      2    187           24

# %%
plt.figure(figsize=(15,6))
plt.title("2021")
sns.barplot(id2021.T);

# %%
# id2021_filtrado = id2021[~id2021['Sexo/Id Sexual o Género'].isin(['Total', 'Desconocido'])]
# id2021_filtrado

# %%
id2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Hombre Cis to Desconocido
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2021    7 non-null      int64
# dtypes: int64(1)
# memory usage: 112.0+ bytes

# %%
id2021.describe()
# Out:
#              2021
# count    7.000000
# mean    56.857143
# std     71.361588
# min      2.000000
# 25%     15.000000
# 50%     24.000000
# 75%     77.500000
# max    187.000000

# %%
or2021
# Out:
#     Orientación  Casos
# 0           Gay    125
# 1      Lesbiana     19
# 2      Bisexual      7
# 3  Heterosexual     12
# 4          Otro      1
# 5         Total    164

# %%
or2021.set_index("Orientación", inplace= True)
or2021.rename(columns = {"Casos" : "2021"}, inplace = True)

# %%
or2021
# Out:
#               2021
# Orientación
# Gay            125
# Lesbiana        19
# Bisexual         7
# Heterosexual    12
# Otro             1
# Total          164

# %%
or2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Gay to Total
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2021    6 non-null      int64
# dtypes: int64(1)
# memory usage: 96.0+ bytes

# %%
or2021.describe()
# Out:
#              2021
# count    6.000000
# mean    54.666667
# std     70.915913
# min      1.000000
# 25%      8.250000
# 50%     15.500000
# 75%     98.500000
# max    164.000000

# %% [markdown]
# Ningún missing value en los DF

# %% [markdown]
# ## ORIENTACION E IDENTIDAD 2022

# %%
id2022
# Out:
#                        2022
# Sexo-id sexual/género
# Hombre Cis              103
# Hombre Trans              5
# Mujer Cis                19
# Mujer Trans              21
# Persona no binaria        4
# Total                   152
# Desconocido              21

# %%
id2022
id2022.set_index("Sexo-id sexual/género", inplace= True)
id2022.rename(columns = {"Casos" : "2022"}, inplace = True)

# %%
id2022 = id2022.copy().T
id2022
# Out:
#                        2022
# Sexo-id sexual/género
# Hombre Cis              103
# Hombre Trans              5
# Mujer Cis                19
# Mujer Trans              21
# Persona no binaria        4
# Total                   152
# Desconocido              21

# %%
# plt.figure(figsize=(12,8))
# sns.kdeplot(id2022[id2022.columns()], fill=True);

# %%
id2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Hombre Cis to Desconocido
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2022    7 non-null      int64
# dtypes: int64(1)
# memory usage: 112.0+ bytes

# %%
id2022.describe()
# Out:
#              2022
# count    7.000000
# mean    46.428571
# std     57.601670
# min      4.000000
# 25%     12.000000
# 50%     21.000000
# 75%     62.000000
# max    152.000000

# %%
or2022
# Out:
#     Orientación  Casos
# 0           Gay    112
# 1      Lesbiana     16
# 2      Bisexual      3
# 3  Heterosexual     12
# 4         Total    143
# 5   Desconocido     42

# %%
# or2022.set_index("Orientación", inplace= True)
or2022.rename(columns = {"Casos" : "2022"}, inplace = True)

# %%
or2022
# Out:
#     Orientación  2022
# 0           Gay   112
# 1      Lesbiana    16
# 2      Bisexual     3
# 3  Heterosexual    12
# 4         Total   143
# 5   Desconocido    42

# %%
or2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Orientación  6 non-null      object
#  1   Casos        6 non-null      int64
#  2   Porcentaje   6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
or2022.describe()
# Out:
#             Casos  Porcentaje
# count    6.000000    6.000000
# mean    54.666667   33.316667
# std     58.711725   43.975148
# min      3.000000    0.000000
# 25%     13.000000    3.675000
# 50%     29.000000    9.750000
# 75%     94.500000   61.500000
# max    143.000000  100.000000

# %% [markdown]
# Ningún missing value en los DF

# %% [markdown]
# ## ORIENTACION E IDENTIDAD 2023

# %%
id2023
# Out:
#   Sexo/Identidad  Casos
# 0     Hombre Cis     94
# 1   Hombre Trans      9
# 2      Mujer Cis     40
# 3    Mujer Trans     35
# 4     No Binaria      9
# 5       Intersex      1
# 6          Total    188
# 7    Desconocido     50

# %%
# id2023
# id2023.set_index("Sexo/Identidad", inplace= True)
# id2023.rename(columns = {"Casos" : "2023"}, inplace = True)
id2023.rename(index = {"No Binaria" : "Persona no binaria"}, inplace = True)

# %%
id2023
# Out:
# array([[ 94],
#        [  9],
#        [ 40],
#        [ 35],
#        [  9],
#        [  1],
#        [188],
#        [ 50]])

# %%
plt.pie([id2023])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18508\2440513273.py in ?()
# ----> 1 plt.pie([id2023])
#
# c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py in ?(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3758     normalize: bool = True,
#    3759     hatch: str | Sequence[str] | None = None,
#    3760     data=None,
#    3761 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3762     return gca().pie(
#    3763         x,
#    3764         explode=explode,
#    3765         labels=labels,
#
# c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py in ?(ax, data, *args, **kwargs)
#    1470     @functools.wraps(func)
#    1471     def inner(ax, *args, data=None, **kwargs):
#    1472         if data is None:
# -> 1473             return func(
#    1474                 ax,
#    1475                 *map(sanitize_sequence, args),
#    1476                 **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#
# c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_axes.py in ?(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3276         """
#    3277         self.set_aspect('equal')
#    3278         # The use of float32 is "historical", but can't be changed without
#    3279         # regenerating the test baselines.
# -> 3280         x = np.asarray(x, np.float32)
#    3281         if x.ndim > 1:
#    3282             raise ValueError("x must be 1D")
#    3283
#
# c:\Users\Alumno Prestamo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Hombre Cis'

# %%
id2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sexo/Identidad  8 non-null      object
#  1   Casos           8 non-null      int64
#  2   Porcentaje      8 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
id2023.describe()
# Out:
#             Casos  Porcentaje
# count    8.000000    8.000000
# mean    53.250000   25.000000
# std     62.086921   34.529449
# min      1.000000    0.000000
# 25%      9.000000    3.725000
# 50%     37.500000   11.700000
# 75%     61.000000   28.475000
# max    188.000000  100.000000

# %%
or2023
# Out:
#   Orientación Sexual  Casos
# 0                Gay     83
# 1           Lesbiana     23
# 2           Bisexual     11
# 3       Heterosexual      8
# 4              Total    125
# 5        Desconocido    113

# %%
or2023.set_index("Orientación Sexual", inplace= True)
or2023.rename(columns = {"Casos" : "2023"}, inplace = True)

# %%
or2023
# Out:
#                     2023
# Orientación Sexual
# Gay                   83
# Lesbiana              23
# Bisexual              11
# Heterosexual           8
# Total                125
# Desconocido          113

# %%
or2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Orientación Sexual  6 non-null      object
#  1   Casos               6 non-null      int64
#  2   Porcentaje          6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
or2023.describe()
# Out:
#             Casos  Porcentaje
# count    6.000000    6.000000
# mean    60.500000   33.333333
# std     52.982072   40.495070
# min      8.000000    0.000000
# 25%     14.000000    7.000000
# 50%     53.000000   13.600000
# 75%    105.500000   54.400000
# max    125.000000  100.000000

# %% [markdown]
# Ningún missing value en los DF

# %%
totalestatal_r = totalestatal
totalestatal_r.rename(columns={'ANDALUCÍA':"AGRESIONES",
                               "TOTAL NACIONAL": "POBLACIÓN"},inplace=True)
totalestatal_r = totalestatal_r.iloc[:,:2]
totalestatal_r['Agresiones por población'] = totalestatal_r['AGRESIONES'] / totalestatal_r['POBLACIÓN']*100
totalestatal_r['Agresiones por población'].mean()
# Out:
# np.float64(14.98817213736146)

# %% [markdown]
# ## ORIENTACION E IDENTIDAD 21-23

# %%
idtotal = pd.concat([id2021,id2022,id2023], axis =1)

# %%
idtotal
# Out:
#                      2021   2022  2023
# Hombre Cis          128.0  103.0    94
# Hombre Trans          9.0    5.0     9
# Mujer Cis            21.0   19.0    40
# Mujer Trans          27.0   21.0    35
# Persona no binaria    2.0    4.0     9
# Total               187.0  152.0   188
# Desconocido          24.0   21.0    50
# Intersex              NaN    NaN     1

# %%
idtotal.fillna(0, inplace = True)
idtotal
# Out:
#                      2021   2022  2023
# Hombre Cis          128.0  103.0    94
# Hombre Trans          9.0    5.0     9
# Mujer Cis            21.0   19.0    40
# Mujer Trans          27.0   21.0    35
# Persona no binaria    2.0    4.0     9
# Total               187.0  152.0   188
# Desconocido          24.0   21.0    50
# Intersex              0.0    0.0     1

# %%
ortotal = pd.concat([or2021,or2022,or2023], axis = 1)

# %%
ortotal
# Out:
#                2021   2022   2023
# Gay           125.0  112.0   83.0
# Lesbiana       19.0   16.0   23.0
# Bisexual        7.0    3.0   11.0
# Heterosexual   12.0   12.0    8.0
# Otro            1.0    NaN    NaN
# Total         164.0  143.0  125.0
# Desconocido     NaN   42.0  113.0

# %%
ortotal.fillna(0, inplace= True)
ortotal
# Out:
#                2021   2022   2023
# Gay           125.0  112.0   83.0
# Lesbiana       19.0   16.0   23.0
# Bisexual        7.0    3.0   11.0
# Heterosexual   12.0   12.0    8.0
# Otro            1.0    0.0    0.0
# Total         164.0  143.0  125.0
# Desconocido     0.0   42.0  113.0

# %%
idortotal = pd.concat([idtotal, ortotal], axis=0)
idortotal.drop("Total", inplace = True)
idortotal = idortotal
idortotal = idortotal.iloc[:,:-2]  # Excluimos las filas "Total" y "Desconocido"
idortotal
# Out:
#                      2021
# Hombre Cis          128.0
# Hombre Trans          9.0
# Mujer Cis            21.0
# Mujer Trans          27.0
# Persona no binaria    2.0
# Desconocido          24.0
# Intersex              0.0
# Gay                 125.0
# Lesbiana             19.0
# Bisexual              7.0
# Heterosexual         12.0
# Otro                  1.0
# Desconocido           0.0

# %%
# plt.figure(figsize=(10, 6))
# idortotal.plot(kind='area', stacked=True)
# plt.title('Gráfico de Área Apilada de Agresiones por Identidad de Género y Orientación Sexual')
# plt.xlabel('Año')
# plt.ylabel('Número de Agresiones')
# plt.legend(title='Identidad de Género y Orientación Sexual', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(False)
# plt.tight_layout()
# plt.show()
