# %%
import pandas as pd
pd.read_csv("data/EDACC.AA._14-23.csv", delimiter = ",")
# Out:
#             ORIENTACIÓN SEXUAL E IDENTIDAD DE GÉNERO  TOTAL NACIONAL  \
# 0                                               2023             530
# 1                                               2022             464
# 2                                               2021             477
# 3                                               2020             282
# 4                                               2019             283
# 5                                               2018             259
# 6                                               2017             271
# 7                                               2016             230
# 8                                               2015             169
# 9                                               2014             513
#
#             ORIENTACIÓN SEXUAL E IDENTIDAD DE GÉNERO.1  ARAGÓN  \
# 0                                                 80        15
# 1                                                 68         9
# ...
